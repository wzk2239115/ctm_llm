# %% [markdown]
# # The Continuous Thought Machine – Tutorial 03: Mazes [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SakanaAI/continuous-thought-machines/blob/main/examples/03_mazes.ipynb) [![arXiv](https://img.shields.io/badge/arXiv-2505.05522-b31b1b.svg)](https://arxiv.org/abs/2505.05522)

# %% [markdown]
# ### Maze Solving
#
# In Section 4 of the [technical report](https://arxiv.org/pdf/2505.05522), we showcase how a CTM can be used to solve 2D mazes. Typically in the literature, the task of solving a maze is described as a form of binary classification: by ensuring the output space matches the dimensions of the input space, a model can classify, for each pixel in the input image, if the pixel belongs to the path through the maze. While this approach has seen success, it excludes the need to think in a more natural fashion. We seek to design a more challenging task, where a more-human like solution is required.

# %% [markdown]
# ### Solving Mazes the Hard Way
#
# Instead of classifying if each pixel in the maze is or is not along the solution path, we instead constrain the output space, such that the model must output a plan: an entire trajectory of actions corresponding to the steps an agent must take to go from the start position to goal position. Specifically, for each internal tick of the CTM, the model produces a sequence of actions. These actions correspond to Left, Right, Up, Down and Wait (or no-op). We can then use a cross-entropy loss function which compares these actions produced by the CTM to the ground-truth trajectory required to solve the maze.

# %% [markdown]
# ### Tutorial Overview

# %% [markdown]
# This tutorial will walk through how to train a CTM to solve mazes the hard way. It is structured as follows:
# 1) Setup
# 2) Data
# 3) Loss Function
# 4) Defining a Training Function
# 5) Initializing the CTM
# 6) Running the Training

# %% [markdown]
# ### Setup

# %% [markdown]
# In addition to installing some dependencies, we also clone the CTM repo (assuming this tutorial is being ran in Colab), so that we can access the base CTM model.

# %%
USE_COLAB = False

# %%
import sys

if USE_COLAB:
    # !git clone https://github.com/SakanaAI/continuous-thought-machines.git
    sys.path.append("./continuous-thought-machines")
else:
    sys.path.append("..")

# %%
# !pip install gdown
# !pip install mediapy
# !git clone https://github.com/SakanaAI/continuous-thought-machines.git
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: gdown in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (6.1.0)
# Requirement already satisfied: beautifulsoup4 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from gdown) (4.14.3)
# Requirement already satisfied: filelock in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from gdown) (3.29.0)
# Requirement already satisfied: requests[socks] in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from gdown) (2.34.2)
# Requirement already satisfied: tqdm in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from requests[socks]->gdown) (3.17)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from requests[socks]->gdown) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from requests[socks]->gdown) (1.7.1)
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: mediapy in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (1.2.6)
# Requirement already satisfied: ipython in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from mediapy) (9.14.0)
# Requirement already satisfied: matplotlib in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from mediapy) (3.10.9)
# Requirement already satisfied: numpy in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from mediapy) (2.4.6)
# Requirement already satisfied: Pillow in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from mediapy) (12.2.0)
# Requirement already satisfied: decorator>=5.1.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (3.0.52)
# Requirement already satisfied: psutil>=7 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (7.0.0)
# Requirement already satisfied: pygments>=2.14.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from ipython->mediapy) (5.15.0)
# Requirement already satisfied: wcwidth in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->mediapy) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from jedi>=0.18.2->ipython->mediapy) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from pexpect>4.6->ipython->mediapy) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->mediapy) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->mediapy) (3.0.1)
# Requirement already satisfied: pure_eval in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython->mediapy) (0.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from matplotlib->mediapy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from matplotlib->mediapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from matplotlib->mediapy) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from matplotlib->mediapy) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from matplotlib->mediapy) (26.0)
# Requirement already satisfied: pyparsing>=3 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from matplotlib->mediapy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from matplotlib->mediapy) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/wzk/miniconda3/envs/ctm/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mediapy) (1.17.0)
# 正克隆到 'continuous-thought-machines'...
# fatal: 无法访问 'https://github.com/SakanaAI/continuous-thought-machines.git/'：GnuTLS recv error (-110): The TLS connection was non-properly terminated.

# %% [markdown]
# Unzip the training and test data (already downloaded locally as `small-mazes.zip`)

# %%
import os

if not os.path.exists("small-mazes"):
    # !unzip -o small-mazes.zip
# Out:
# Archive:  small-mazes.zip
#    creating: small-mazes/
#   inflating: __MACOSX/._small-mazes
#   inflating: small-mazes/.DS_Store
#   inflating: __MACOSX/small-mazes/._.DS_Store
#    creating: small-mazes/test/
#   inflating: __MACOSX/small-mazes/._test
#    creating: small-mazes/train/
#   inflating: __MACOSX/small-mazes/._train
#   inflating: small-mazes/test/.DS_Store
#   inflating: __MACOSX/small-mazes/test/._.DS_Store
#    creating: small-mazes/test/0/
#   inflating: __MACOSX/small-mazes/test/._0
#   inflating: small-mazes/train/.DS_Store
#   inflating: __MACOSX/small-mazes/train/._.DS_Store
#    creating: small-mazes/train/0/
#   inflating: __MACOSX/small-mazes/train/._0
#   inflating: small-mazes/test/0/348.png
#   inflating: __MACOSX/small-mazes/test/0/._348.png
#   inflating: small-mazes/test/0/412.png
#   inflating: __MACOSX/small-mazes/test/0/._412.png
#   inflating: small-mazes/test/0/374.png
#   inflating: __MACOSX/small-mazes/test/0/._374.png
#   inflating: small-mazes/test/0/360.png
#   inflating: __MACOSX/small-mazes/test/0/._360.png
#   inflating: small-mazes/test/0/406.png
#   inflating: __MACOSX/small-mazes/test/0/._406.png
#   inflating: small-mazes/test/0/638.png
#   inflating: __MACOSX/small-mazes/test/0/._638.png
#   inflating: small-mazes/test/0/176.png
#   inflating: __MACOSX/small-mazes/test/0/._176.png
#   inflating: small-mazes/test/0/88.png
#   inflating: __MACOSX/small-mazes/test/0/._88.png
#   inflating: small-mazes/test/0/610.png
#   inflating: __MACOSX/small-mazes/test/0/._610.png
#   inflating: small-mazes/test/0/604.png
#   inflating: __MACOSX/small-mazes/test/0/._604.png
#   inflating: small-mazes/test/0/162.png
#   inflating: __MACOSX/small-mazes/test/0/._162.png
#   inflating: small-mazes/test/0/189.png
#   inflating: __MACOSX/small-mazes/test/0/._189.png
#   inflating: small-mazes/test/0/837.png
#   inflating: __MACOSX/small-mazes/test/0/._837.png
#   inflating: small-mazes/test/0/77.png
#   inflating: __MACOSX/small-mazes/test/0/._77.png
#   inflating: small-mazes/test/0/823.png
#   inflating: __MACOSX/small-mazes/test/0/._823.png
#   inflating: small-mazes/test/0/63.png
#   inflating: __MACOSX/small-mazes/test/0/._63.png
#   inflating: small-mazes/test/0/980.png
#   inflating: __MACOSX/small-mazes/test/0/._980.png
#   inflating: small-mazes/test/0/758.png
#   inflating: __MACOSX/small-mazes/test/0/._758.png
#   inflating: small-mazes/test/0/994.png
#   inflating: __MACOSX/small-mazes/test/0/._994.png
#   inflating: small-mazes/test/0/764.png
#   inflating: __MACOSX/small-mazes/test/0/._764.png
#   inflating: small-mazes/test/0/770.png
#   inflating: __MACOSX/small-mazes/test/0/._770.png
#   inflating: small-mazes/test/0/943.png
#   inflating: __MACOSX/small-mazes/test/0/._943.png
#   inflating: small-mazes/test/0/957.png
#   inflating: __MACOSX/small-mazes/test/0/._957.png
#   inflating: small-mazes/test/0/228.png
#   inflating: __MACOSX/small-mazes/test/0/._228.png
#   inflating: small-mazes/test/0/566.png
#   inflating: __MACOSX/small-mazes/test/0/._566.png
#   inflating: small-mazes/test/0/200.png
#   inflating: __MACOSX/small-mazes/test/0/._200.png
#   inflating: small-mazes/test/0/214.png
#   inflating: __MACOSX/small-mazes/test/0/._214.png
#   inflating: small-mazes/test/0/572.png
#   inflating: __MACOSX/small-mazes/test/0/._572.png
#   inflating: small-mazes/test/0/599.png
#   inflating: __MACOSX/small-mazes/test/0/._599.png
#   inflating: small-mazes/test/0/598.png
#   inflating: __MACOSX/small-mazes/test/0/._598.png
#   inflating: small-mazes/test/0/215.png
#   inflating: __MACOSX/small-mazes/test/0/._215.png
#   inflating: small-mazes/test/0/573.png
#   inflating: __MACOSX/small-mazes/test/0/._573.png
#   inflating: small-mazes/test/0/567.png
#   inflating: __MACOSX/small-mazes/test/0/._567.png
#   inflating: small-mazes/test/0/201.png
#   inflating: __MACOSX/small-mazes/test/0/._201.png
#   inflating: small-mazes/test/0/229.png
#   inflating: __MACOSX/small-mazes/test/0/._229.png
#   inflating: small-mazes/test/0/956.png
#   inflating: __MACOSX/small-mazes/test/0/._956.png
#   inflating: small-mazes/test/0/942.png
#   inflating: __MACOSX/small-mazes/test/0/._942.png
#   inflating: small-mazes/test/0/771.png
#   inflating: __MACOSX/small-mazes/test/0/._771.png
#   inflating: small-mazes/test/0/765.png
#   inflating: __MACOSX/small-mazes/test/0/._765.png
#   inflating: small-mazes/test/0/995.png
#   inflating: __MACOSX/small-mazes/test/0/._995.png
#   inflating: small-mazes/test/0/759.png
#   inflating: __MACOSX/small-mazes/test/0/._759.png
#   inflating: small-mazes/test/0/981.png
#   inflating: __MACOSX/small-mazes/test/0/._981.png
#   inflating: small-mazes/test/0/62.png
#   inflating: __MACOSX/small-mazes/test/0/._62.png
#   inflating: small-mazes/test/0/822.png
#   inflating: __MACOSX/small-mazes/test/0/._822.png
#   inflating: small-mazes/test/0/188.png
#   inflating: __MACOSX/small-mazes/test/0/._188.png
#   inflating: small-mazes/test/0/76.png
#   inflating: __MACOSX/small-mazes/test/0/._76.png
#   inflating: small-mazes/test/0/836.png
#   inflating: __MACOSX/small-mazes/test/0/._836.png
#   inflating: small-mazes/test/0/605.png
#   inflating: __MACOSX/small-mazes/test/0/._605.png
#   inflating: small-mazes/test/0/163.png
#   inflating: __MACOSX/small-mazes/test/0/._163.png
#   inflating: small-mazes/test/0/177.png
#   inflating: __MACOSX/small-mazes/test/0/._177.png
#   inflating: small-mazes/test/0/611.png
#   inflating: __MACOSX/small-mazes/test/0/._611.png
#   inflating: small-mazes/test/0/89.png
#   inflating: __MACOSX/small-mazes/test/0/._89.png
#   inflating: small-mazes/test/0/639.png
#   inflating: __MACOSX/small-mazes/test/0/._639.png
#   inflating: small-mazes/test/0/361.png
#   inflating: __MACOSX/small-mazes/test/0/._361.png
#   inflating: small-mazes/test/0/407.png
#   inflating: __MACOSX/small-mazes/test/0/._407.png
#   inflating: small-mazes/test/0/413.png
#   inflating: __MACOSX/small-mazes/test/0/._413.png
#   inflating: small-mazes/test/0/375.png
#   inflating: __MACOSX/small-mazes/test/0/._375.png
#   inflating: small-mazes/test/0/349.png
#   inflating: __MACOSX/small-mazes/test/0/._349.png
#   inflating: small-mazes/test/0/439.png
#   inflating: __MACOSX/small-mazes/test/0/._439.png
#   inflating: small-mazes/test/0/405.png
#   inflating: __MACOSX/small-mazes/test/0/._405.png
#   inflating: small-mazes/test/0/363.png
#   inflating: __MACOSX/small-mazes/test/0/._363.png
#   inflating: small-mazes/test/0/377.png
#   inflating: __MACOSX/small-mazes/test/0/._377.png
#   inflating: small-mazes/test/0/411.png
#   inflating: __MACOSX/small-mazes/test/0/._411.png
#   inflating: small-mazes/test/0/388.png
#   inflating: __MACOSX/small-mazes/test/0/._388.png
#   inflating: small-mazes/test/0/149.png
#   inflating: __MACOSX/small-mazes/test/0/._149.png
#   inflating: small-mazes/test/0/161.png
#   inflating: __MACOSX/small-mazes/test/0/._161.png
#   inflating: small-mazes/test/0/607.png
#   inflating: __MACOSX/small-mazes/test/0/._607.png
#   inflating: small-mazes/test/0/613.png
#   inflating: __MACOSX/small-mazes/test/0/._613.png
#   inflating: small-mazes/test/0/175.png
#   inflating: __MACOSX/small-mazes/test/0/._175.png
#   inflating: small-mazes/test/0/820.png
#   inflating: __MACOSX/small-mazes/test/0/._820.png
#   inflating: small-mazes/test/0/60.png
#   inflating: __MACOSX/small-mazes/test/0/._60.png
#   inflating: small-mazes/test/0/834.png
#   inflating: __MACOSX/small-mazes/test/0/._834.png
#   inflating: small-mazes/test/0/74.png
#   inflating: __MACOSX/small-mazes/test/0/._74.png
#   inflating: small-mazes/test/0/808.png
#   inflating: __MACOSX/small-mazes/test/0/._808.png
#   inflating: small-mazes/test/0/48.png
#   inflating: __MACOSX/small-mazes/test/0/._48.png
#   inflating: small-mazes/test/0/997.png
#   inflating: __MACOSX/small-mazes/test/0/._997.png
#   inflating: small-mazes/test/0/983.png
#   inflating: __MACOSX/small-mazes/test/0/._983.png
#   inflating: small-mazes/test/0/773.png
#   inflating: __MACOSX/small-mazes/test/0/._773.png
#   inflating: small-mazes/test/0/767.png
#   inflating: __MACOSX/small-mazes/test/0/._767.png
#   inflating: small-mazes/test/0/954.png
#   inflating: __MACOSX/small-mazes/test/0/._954.png
#   inflating: small-mazes/test/0/798.png
#   inflating: __MACOSX/small-mazes/test/0/._798.png
#   inflating: small-mazes/test/0/940.png
#   inflating: __MACOSX/small-mazes/test/0/._940.png
#   inflating: small-mazes/test/0/968.png
#   inflating: __MACOSX/small-mazes/test/0/._968.png
#   inflating: small-mazes/test/0/559.png
#   inflating: __MACOSX/small-mazes/test/0/._559.png
#   inflating: small-mazes/test/0/571.png
#   inflating: __MACOSX/small-mazes/test/0/._571.png
#   inflating: small-mazes/test/0/217.png
#   inflating: __MACOSX/small-mazes/test/0/._217.png
#   inflating: small-mazes/test/0/203.png
#   inflating: __MACOSX/small-mazes/test/0/._203.png
#   inflating: small-mazes/test/0/565.png
#   inflating: __MACOSX/small-mazes/test/0/._565.png
#   inflating: small-mazes/test/0/202.png
#   inflating: __MACOSX/small-mazes/test/0/._202.png
#   inflating: small-mazes/test/0/564.png
#   inflating: __MACOSX/small-mazes/test/0/._564.png
#   inflating: small-mazes/test/0/570.png
#   inflating: __MACOSX/small-mazes/test/0/._570.png
#   inflating: small-mazes/test/0/216.png
#   inflating: __MACOSX/small-mazes/test/0/._216.png
#   inflating: small-mazes/test/0/558.png
#   inflating: __MACOSX/small-mazes/test/0/._558.png
#   inflating: small-mazes/test/0/969.png
#   inflating: __MACOSX/small-mazes/test/0/._969.png
#   inflating: small-mazes/test/0/941.png
#   inflating: __MACOSX/small-mazes/test/0/._941.png
#   inflating: small-mazes/test/0/799.png
#   inflating: __MACOSX/small-mazes/test/0/._799.png
#   inflating: small-mazes/test/0/955.png
#   inflating: __MACOSX/small-mazes/test/0/._955.png
#   inflating: small-mazes/test/0/766.png
#   inflating: __MACOSX/small-mazes/test/0/._766.png
#   inflating: small-mazes/test/0/772.png
#   inflating: __MACOSX/small-mazes/test/0/._772.png
#   inflating: small-mazes/test/0/982.png
#   inflating: __MACOSX/small-mazes/test/0/._982.png
#   inflating: small-mazes/test/0/996.png
#   inflating: __MACOSX/small-mazes/test/0/._996.png
#   inflating: small-mazes/test/0/49.png
#   inflating: __MACOSX/small-mazes/test/0/._49.png
#   inflating: small-mazes/test/0/809.png
#   inflating: __MACOSX/small-mazes/test/0/._809.png
#   inflating: small-mazes/test/0/75.png
#   inflating: __MACOSX/small-mazes/test/0/._75.png
#   inflating: small-mazes/test/0/835.png
#   inflating: __MACOSX/small-mazes/test/0/._835.png
#   inflating: small-mazes/test/0/61.png
#   inflating: __MACOSX/small-mazes/test/0/._61.png
#   inflating: small-mazes/test/0/821.png
#   inflating: __MACOSX/small-mazes/test/0/._821.png
#   inflating: small-mazes/test/0/612.png
#   inflating: __MACOSX/small-mazes/test/0/._612.png
#   inflating: small-mazes/test/0/174.png
#   inflating: __MACOSX/small-mazes/test/0/._174.png
#   inflating: small-mazes/test/0/160.png
#   inflating: __MACOSX/small-mazes/test/0/._160.png
#   inflating: small-mazes/test/0/606.png
#   inflating: __MACOSX/small-mazes/test/0/._606.png
#   inflating: small-mazes/test/0/148.png
#   inflating: __MACOSX/small-mazes/test/0/._148.png
#   inflating: small-mazes/test/0/389.png
#   inflating: __MACOSX/small-mazes/test/0/._389.png
#   inflating: small-mazes/test/0/376.png
#   inflating: __MACOSX/small-mazes/test/0/._376.png
#   inflating: small-mazes/test/0/410.png
#   inflating: __MACOSX/small-mazes/test/0/._410.png
#   inflating: small-mazes/test/0/404.png
#   inflating: __MACOSX/small-mazes/test/0/._404.png
#   inflating: small-mazes/test/0/362.png
#   inflating: __MACOSX/small-mazes/test/0/._362.png
#   inflating: small-mazes/test/0/438.png
#   inflating: __MACOSX/small-mazes/test/0/._438.png
#   inflating: small-mazes/test/0/366.png
#   inflating: __MACOSX/small-mazes/test/0/._366.png
#   inflating: small-mazes/test/0/400.png
#   inflating: __MACOSX/small-mazes/test/0/._400.png
#   inflating: small-mazes/test/0/414.png
#   inflating: __MACOSX/small-mazes/test/0/._414.png
#   inflating: small-mazes/test/0/372.png
#   inflating: __MACOSX/small-mazes/test/0/._372.png
#   inflating: small-mazes/test/0/428.png
#   inflating: __MACOSX/small-mazes/test/0/._428.png
#   inflating: small-mazes/test/0/399.png
#   inflating: __MACOSX/small-mazes/test/0/._399.png
#   inflating: small-mazes/test/0/602.png
#   inflating: __MACOSX/small-mazes/test/0/._602.png
#   inflating: small-mazes/test/0/164.png
#   inflating: __MACOSX/small-mazes/test/0/._164.png
#   inflating: small-mazes/test/0/170.png
#   inflating: __MACOSX/small-mazes/test/0/._170.png
#   inflating: small-mazes/test/0/616.png
#   inflating: __MACOSX/small-mazes/test/0/._616.png
#   inflating: small-mazes/test/0/158.png
#   inflating: __MACOSX/small-mazes/test/0/._158.png
#   inflating: small-mazes/test/0/819.png
#   inflating: __MACOSX/small-mazes/test/0/._819.png
#   inflating: small-mazes/test/0/59.png
#   inflating: __MACOSX/small-mazes/test/0/._59.png
#   inflating: small-mazes/test/0/825.png
#   inflating: __MACOSX/small-mazes/test/0/._825.png
#   inflating: small-mazes/test/0/65.png
#   inflating: __MACOSX/small-mazes/test/0/._65.png
#   inflating: small-mazes/test/0/831.png
#   inflating: __MACOSX/small-mazes/test/0/._831.png
#   inflating: small-mazes/test/0/71.png
#   inflating: __MACOSX/small-mazes/test/0/._71.png
#   inflating: small-mazes/test/0/776.png
#   inflating: __MACOSX/small-mazes/test/0/._776.png
#   inflating: small-mazes/test/0/762.png
#   inflating: __MACOSX/small-mazes/test/0/._762.png
#   inflating: small-mazes/test/0/992.png
#   inflating: __MACOSX/small-mazes/test/0/._992.png
#   inflating: small-mazes/test/0/986.png
#   inflating: __MACOSX/small-mazes/test/0/._986.png
#   inflating: small-mazes/test/0/979.png
#   inflating: __MACOSX/small-mazes/test/0/._979.png
#   inflating: small-mazes/test/0/789.png
#   inflating: __MACOSX/small-mazes/test/0/._789.png
#   inflating: small-mazes/test/0/951.png
#   inflating: __MACOSX/small-mazes/test/0/._951.png
#   inflating: small-mazes/test/0/945.png
#   inflating: __MACOSX/small-mazes/test/0/._945.png
#   inflating: small-mazes/test/0/212.png
#   inflating: __MACOSX/small-mazes/test/0/._212.png
#   inflating: small-mazes/test/0/.DS_Store
#   inflating: __MACOSX/small-mazes/test/0/._.DS_Store
#   inflating: small-mazes/test/0/574.png
#   inflating: __MACOSX/small-mazes/test/0/._574.png
#   inflating: small-mazes/test/0/560.png
#   inflating: __MACOSX/small-mazes/test/0/._560.png
#   inflating: small-mazes/test/0/206.png
#   inflating: __MACOSX/small-mazes/test/0/._206.png
#   inflating: small-mazes/test/0/548.png
#   inflating: __MACOSX/small-mazes/test/0/._548.png
#   inflating: small-mazes/test/0/549.png
#   inflating: __MACOSX/small-mazes/test/0/._549.png
#   inflating: small-mazes/test/0/561.png
#   inflating: __MACOSX/small-mazes/test/0/._561.png
#   inflating: small-mazes/test/0/207.png
#   inflating: __MACOSX/small-mazes/test/0/._207.png
#   inflating: small-mazes/test/0/213.png
#   inflating: __MACOSX/small-mazes/test/0/._213.png
#   inflating: small-mazes/test/0/575.png
#   inflating: __MACOSX/small-mazes/test/0/._575.png
#   inflating: small-mazes/test/0/944.png
#   inflating: __MACOSX/small-mazes/test/0/._944.png
#   inflating: small-mazes/test/0/950.png
#   inflating: __MACOSX/small-mazes/test/0/._950.png
#   inflating: small-mazes/test/0/788.png
#   inflating: __MACOSX/small-mazes/test/0/._788.png
#   inflating: small-mazes/test/0/978.png
#   inflating: __MACOSX/small-mazes/test/0/._978.png
#   inflating: small-mazes/test/0/987.png
#   inflating: __MACOSX/small-mazes/test/0/._987.png
#   inflating: small-mazes/test/0/993.png
#   inflating: __MACOSX/small-mazes/test/0/._993.png
#   inflating: small-mazes/test/0/763.png
#   inflating: __MACOSX/small-mazes/test/0/._763.png
#   inflating: small-mazes/test/0/777.png
#   inflating: __MACOSX/small-mazes/test/0/._777.png
#   inflating: small-mazes/test/0/70.png
#   inflating: __MACOSX/small-mazes/test/0/._70.png
#   inflating: small-mazes/test/0/830.png
#   inflating: __MACOSX/small-mazes/test/0/._830.png
#   inflating: small-mazes/test/0/64.png
#   inflating: __MACOSX/small-mazes/test/0/._64.png
#   inflating: small-mazes/test/0/824.png
#   inflating: __MACOSX/small-mazes/test/0/._824.png
#   inflating: small-mazes/test/0/58.png
#   inflating: __MACOSX/small-mazes/test/0/._58.png
#   inflating: small-mazes/test/0/818.png
#   inflating: __MACOSX/small-mazes/test/0/._818.png
#   inflating: small-mazes/test/0/159.png
#   inflating: __MACOSX/small-mazes/test/0/._159.png
#   inflating: small-mazes/test/0/171.png
#   inflating: __MACOSX/small-mazes/test/0/._171.png
#   inflating: small-mazes/test/0/617.png
#   inflating: __MACOSX/small-mazes/test/0/._617.png
#   inflating: small-mazes/test/0/603.png
#   inflating: __MACOSX/small-mazes/test/0/._603.png
#   inflating: small-mazes/test/0/165.png
#   inflating: __MACOSX/small-mazes/test/0/._165.png
#   inflating: small-mazes/test/0/398.png
#   inflating: __MACOSX/small-mazes/test/0/._398.png
#   inflating: small-mazes/test/0/429.png
#   inflating: __MACOSX/small-mazes/test/0/._429.png
#   inflating: small-mazes/test/0/415.png
#   inflating: __MACOSX/small-mazes/test/0/._415.png
#   inflating: small-mazes/test/0/373.png
#   inflating: __MACOSX/small-mazes/test/0/._373.png
#   inflating: small-mazes/test/0/367.png
#   inflating: __MACOSX/small-mazes/test/0/._367.png
#   inflating: small-mazes/test/0/401.png
#   inflating: __MACOSX/small-mazes/test/0/._401.png
#   inflating: small-mazes/test/0/371.png
#   inflating: __MACOSX/small-mazes/test/0/._371.png
#   inflating: small-mazes/test/0/417.png
#   inflating: __MACOSX/small-mazes/test/0/._417.png
#   inflating: small-mazes/test/0/403.png
#   inflating: __MACOSX/small-mazes/test/0/._403.png
#   inflating: small-mazes/test/0/365.png
#   inflating: __MACOSX/small-mazes/test/0/._365.png
#   inflating: small-mazes/test/0/359.png
#   inflating: __MACOSX/small-mazes/test/0/._359.png
#   inflating: small-mazes/test/0/615.png
#   inflating: __MACOSX/small-mazes/test/0/._615.png
#   inflating: small-mazes/test/0/173.png
#   inflating: __MACOSX/small-mazes/test/0/._173.png
#   inflating: small-mazes/test/0/167.png
#   inflating: __MACOSX/small-mazes/test/0/._167.png
#   inflating: small-mazes/test/0/601.png
#   inflating: __MACOSX/small-mazes/test/0/._601.png
#   inflating: small-mazes/test/0/99.png
#   inflating: __MACOSX/small-mazes/test/0/._99.png
#   inflating: small-mazes/test/0/629.png
#   inflating: __MACOSX/small-mazes/test/0/._629.png
#   inflating: small-mazes/test/0/8.png
#   inflating: __MACOSX/small-mazes/test/0/._8.png
#   inflating: small-mazes/test/0/832.png
#   inflating: __MACOSX/small-mazes/test/0/._832.png
#   inflating: small-mazes/test/0/72.png
#   inflating: __MACOSX/small-mazes/test/0/._72.png
#   inflating: small-mazes/test/0/198.png
#   inflating: __MACOSX/small-mazes/test/0/._198.png
#   inflating: small-mazes/test/0/826.png
#   inflating: __MACOSX/small-mazes/test/0/._826.png
#   inflating: small-mazes/test/0/66.png
#   inflating: __MACOSX/small-mazes/test/0/._66.png
#   inflating: small-mazes/test/0/761.png
#   inflating: __MACOSX/small-mazes/test/0/._761.png
#   inflating: small-mazes/test/0/775.png
#   inflating: __MACOSX/small-mazes/test/0/._775.png
#   inflating: small-mazes/test/0/985.png
#   inflating: __MACOSX/small-mazes/test/0/._985.png
#   inflating: small-mazes/test/0/991.png
#   inflating: __MACOSX/small-mazes/test/0/._991.png
#   inflating: small-mazes/test/0/749.png
#   inflating: __MACOSX/small-mazes/test/0/._749.png
#   inflating: small-mazes/test/0/946.png
#   inflating: __MACOSX/small-mazes/test/0/._946.png
#   inflating: small-mazes/test/0/952.png
#   inflating: __MACOSX/small-mazes/test/0/._952.png
#   inflating: small-mazes/test/0/205.png
#   inflating: __MACOSX/small-mazes/test/0/._205.png
#   inflating: small-mazes/test/0/563.png
#   inflating: __MACOSX/small-mazes/test/0/._563.png
#   inflating: small-mazes/test/0/577.png
#   inflating: __MACOSX/small-mazes/test/0/._577.png
#   inflating: small-mazes/test/0/211.png
#   inflating: __MACOSX/small-mazes/test/0/._211.png
#   inflating: small-mazes/test/0/239.png
#   inflating: __MACOSX/small-mazes/test/0/._239.png
#   inflating: small-mazes/test/0/588.png
#   inflating: __MACOSX/small-mazes/test/0/._588.png
#   inflating: small-mazes/test/0/589.png
#   inflating: __MACOSX/small-mazes/test/0/._589.png
#   inflating: small-mazes/test/0/238.png
#   inflating: __MACOSX/small-mazes/test/0/._238.png
#   inflating: small-mazes/test/0/576.png
#   inflating: __MACOSX/small-mazes/test/0/._576.png
#   inflating: small-mazes/test/0/210.png
#   inflating: __MACOSX/small-mazes/test/0/._210.png
#   inflating: small-mazes/test/0/204.png
#   inflating: __MACOSX/small-mazes/test/0/._204.png
#   inflating: small-mazes/test/0/562.png
#   inflating: __MACOSX/small-mazes/test/0/._562.png
#   inflating: small-mazes/test/0/953.png
#   inflating: __MACOSX/small-mazes/test/0/._953.png
#   inflating: small-mazes/test/0/947.png
#   inflating: __MACOSX/small-mazes/test/0/._947.png
#   inflating: small-mazes/test/0/748.png
#   inflating: __MACOSX/small-mazes/test/0/._748.png
#   inflating: small-mazes/test/0/990.png
#   inflating: __MACOSX/small-mazes/test/0/._990.png
#   inflating: small-mazes/test/0/984.png
#   inflating: __MACOSX/small-mazes/test/0/._984.png
#   inflating: small-mazes/test/0/774.png
#   inflating: __MACOSX/small-mazes/test/0/._774.png
#   inflating: small-mazes/test/0/760.png
#   inflating: __MACOSX/small-mazes/test/0/._760.png
#   inflating: small-mazes/test/0/199.png
#   inflating: __MACOSX/small-mazes/test/0/._199.png
#   inflating: small-mazes/test/0/67.png
#   inflating: __MACOSX/small-mazes/test/0/._67.png
#   inflating: small-mazes/test/0/827.png
#   inflating: __MACOSX/small-mazes/test/0/._827.png
#   inflating: small-mazes/test/0/73.png
#   inflating: __MACOSX/small-mazes/test/0/._73.png
#   inflating: small-mazes/test/0/833.png
#   inflating: __MACOSX/small-mazes/test/0/._833.png
#   inflating: small-mazes/test/0/9.png
#   inflating: __MACOSX/small-mazes/test/0/._9.png
#   inflating: small-mazes/test/0/628.png
#   inflating: __MACOSX/small-mazes/test/0/._628.png
#   inflating: small-mazes/test/0/166.png
#   inflating: __MACOSX/small-mazes/test/0/._166.png
#   inflating: small-mazes/test/0/98.png
#   inflating: __MACOSX/small-mazes/test/0/._98.png
#   inflating: small-mazes/test/0/600.png
#   inflating: __MACOSX/small-mazes/test/0/._600.png
#   inflating: small-mazes/test/0/614.png
#   inflating: __MACOSX/small-mazes/test/0/._614.png
#   inflating: small-mazes/test/0/172.png
#   inflating: __MACOSX/small-mazes/test/0/._172.png
#   inflating: small-mazes/test/0/358.png
#   inflating: __MACOSX/small-mazes/test/0/._358.png
#   inflating: small-mazes/test/0/402.png
#   inflating: __MACOSX/small-mazes/test/0/._402.png
#   inflating: small-mazes/test/0/364.png
#   inflating: __MACOSX/small-mazes/test/0/._364.png
#   inflating: small-mazes/test/0/370.png
#   inflating: __MACOSX/small-mazes/test/0/._370.png
#   inflating: small-mazes/test/0/416.png
#   inflating: __MACOSX/small-mazes/test/0/._416.png
#   inflating: small-mazes/test/0/459.png
#   inflating: __MACOSX/small-mazes/test/0/._459.png
#   inflating: small-mazes/test/0/317.png
#   inflating: __MACOSX/small-mazes/test/0/._317.png
#   inflating: small-mazes/test/0/471.png
#   inflating: __MACOSX/small-mazes/test/0/._471.png
#   inflating: small-mazes/test/0/465.png
#   inflating: __MACOSX/small-mazes/test/0/._465.png
#   inflating: small-mazes/test/0/303.png
#   inflating: __MACOSX/small-mazes/test/0/._303.png
#   inflating: small-mazes/test/0/897.png
#   inflating: __MACOSX/small-mazes/test/0/._897.png
#   inflating: small-mazes/test/0/129.png
#   inflating: __MACOSX/small-mazes/test/0/._129.png
#   inflating: small-mazes/test/0/883.png
#   inflating: __MACOSX/small-mazes/test/0/._883.png
#   inflating: small-mazes/test/0/673.png
#   inflating: __MACOSX/small-mazes/test/0/._673.png
#   inflating: small-mazes/test/0/115.png
#   inflating: __MACOSX/small-mazes/test/0/._115.png
#   inflating: small-mazes/test/0/101.png
#   inflating: __MACOSX/small-mazes/test/0/._101.png
#   inflating: small-mazes/test/0/667.png
#   inflating: __MACOSX/small-mazes/test/0/._667.png
#   inflating: small-mazes/test/0/854.png
#   inflating: __MACOSX/small-mazes/test/0/._854.png
#   inflating: small-mazes/test/0/14.png
#   inflating: __MACOSX/small-mazes/test/0/._14.png
#   inflating: small-mazes/test/0/840.png
#   inflating: __MACOSX/small-mazes/test/0/._840.png
#   inflating: small-mazes/test/0/698.png
#   inflating: __MACOSX/small-mazes/test/0/._698.png
#   inflating: small-mazes/test/0/868.png
#   inflating: __MACOSX/small-mazes/test/0/._868.png
#   inflating: small-mazes/test/0/28.png
#   inflating: __MACOSX/small-mazes/test/0/._28.png
#   inflating: small-mazes/test/0/707.png
#   inflating: __MACOSX/small-mazes/test/0/._707.png
#   inflating: small-mazes/test/0/713.png
#   inflating: __MACOSX/small-mazes/test/0/._713.png
#   inflating: small-mazes/test/0/920.png
#   inflating: __MACOSX/small-mazes/test/0/._920.png
#   inflating: small-mazes/test/0/934.png
#   inflating: __MACOSX/small-mazes/test/0/._934.png
#   inflating: small-mazes/test/0/908.png
#   inflating: __MACOSX/small-mazes/test/0/._908.png
#   inflating: small-mazes/test/0/539.png
#   inflating: __MACOSX/small-mazes/test/0/._539.png
#   inflating: small-mazes/test/0/263.png
#   inflating: __MACOSX/small-mazes/test/0/._263.png
#   inflating: small-mazes/test/0/505.png
#   inflating: __MACOSX/small-mazes/test/0/._505.png
#   inflating: small-mazes/test/0/511.png
#   inflating: __MACOSX/small-mazes/test/0/._511.png
#   inflating: small-mazes/test/0/277.png
#   inflating: __MACOSX/small-mazes/test/0/._277.png
#   inflating: small-mazes/test/0/288.png
#   inflating: __MACOSX/small-mazes/test/0/._288.png
#   inflating: small-mazes/test/0/289.png
#   inflating: __MACOSX/small-mazes/test/0/._289.png
#   inflating: small-mazes/test/0/510.png
#   inflating: __MACOSX/small-mazes/test/0/._510.png
#   inflating: small-mazes/test/0/276.png
#   inflating: __MACOSX/small-mazes/test/0/._276.png
#   inflating: small-mazes/test/0/262.png
#   inflating: __MACOSX/small-mazes/test/0/._262.png
#   inflating: small-mazes/test/0/504.png
#   inflating: __MACOSX/small-mazes/test/0/._504.png
#   inflating: small-mazes/test/0/538.png
#   inflating: __MACOSX/small-mazes/test/0/._538.png
#   inflating: small-mazes/test/0/909.png
#   inflating: __MACOSX/small-mazes/test/0/._909.png
#   inflating: small-mazes/test/0/935.png
#   inflating: __MACOSX/small-mazes/test/0/._935.png
#   inflating: small-mazes/test/0/921.png
#   inflating: __MACOSX/small-mazes/test/0/._921.png
#   inflating: small-mazes/test/0/712.png
#   inflating: __MACOSX/small-mazes/test/0/._712.png
#   inflating: small-mazes/test/0/706.png
#   inflating: __MACOSX/small-mazes/test/0/._706.png
#   inflating: small-mazes/test/0/29.png
#   inflating: __MACOSX/small-mazes/test/0/._29.png
#   inflating: small-mazes/test/0/869.png
#   inflating: __MACOSX/small-mazes/test/0/._869.png
#   inflating: small-mazes/test/0/699.png
#   inflating: __MACOSX/small-mazes/test/0/._699.png
#   inflating: small-mazes/test/0/841.png
#   inflating: __MACOSX/small-mazes/test/0/._841.png
#   inflating: small-mazes/test/0/15.png
#   inflating: __MACOSX/small-mazes/test/0/._15.png
#   inflating: small-mazes/test/0/855.png
#   inflating: __MACOSX/small-mazes/test/0/._855.png
#   inflating: small-mazes/test/0/100.png
#   inflating: __MACOSX/small-mazes/test/0/._100.png
#   inflating: small-mazes/test/0/666.png
#   inflating: __MACOSX/small-mazes/test/0/._666.png
#   inflating: small-mazes/test/0/672.png
#   inflating: __MACOSX/small-mazes/test/0/._672.png
#   inflating: small-mazes/test/0/114.png
#   inflating: __MACOSX/small-mazes/test/0/._114.png
#   inflating: small-mazes/test/0/882.png
#   inflating: __MACOSX/small-mazes/test/0/._882.png
#   inflating: small-mazes/test/0/896.png
#   inflating: __MACOSX/small-mazes/test/0/._896.png
#   inflating: small-mazes/test/0/128.png
#   inflating: __MACOSX/small-mazes/test/0/._128.png
#   inflating: small-mazes/test/0/464.png
#   inflating: __MACOSX/small-mazes/test/0/._464.png
#   inflating: small-mazes/test/0/302.png
#   inflating: __MACOSX/small-mazes/test/0/._302.png
#   inflating: small-mazes/test/0/316.png
#   inflating: __MACOSX/small-mazes/test/0/._316.png
#   inflating: small-mazes/test/0/470.png
#   inflating: __MACOSX/small-mazes/test/0/._470.png
#   inflating: small-mazes/test/0/458.png
#   inflating: __MACOSX/small-mazes/test/0/._458.png
#   inflating: small-mazes/test/0/328.png
#   inflating: __MACOSX/small-mazes/test/0/._328.png
#   inflating: small-mazes/test/0/300.png
#   inflating: __MACOSX/small-mazes/test/0/._300.png
#   inflating: small-mazes/test/0/466.png
#   inflating: __MACOSX/small-mazes/test/0/._466.png
#   inflating: small-mazes/test/0/472.png
#   inflating: __MACOSX/small-mazes/test/0/._472.png
#   inflating: small-mazes/test/0/314.png
#   inflating: __MACOSX/small-mazes/test/0/._314.png
#   inflating: small-mazes/test/0/499.png
#   inflating: __MACOSX/small-mazes/test/0/._499.png
#   inflating: small-mazes/test/0/658.png
#   inflating: __MACOSX/small-mazes/test/0/._658.png
#   inflating: small-mazes/test/0/880.png
#   inflating: __MACOSX/small-mazes/test/0/._880.png
#   inflating: small-mazes/test/0/894.png
#   inflating: __MACOSX/small-mazes/test/0/._894.png
#   inflating: small-mazes/test/0/664.png
#   inflating: __MACOSX/small-mazes/test/0/._664.png
#   inflating: small-mazes/test/0/102.png
#   inflating: __MACOSX/small-mazes/test/0/._102.png
#   inflating: small-mazes/test/0/116.png
#   inflating: __MACOSX/small-mazes/test/0/._116.png
#   inflating: small-mazes/test/0/670.png
#   inflating: __MACOSX/small-mazes/test/0/._670.png
#   inflating: small-mazes/test/0/843.png
#   inflating: __MACOSX/small-mazes/test/0/._843.png
#   inflating: small-mazes/test/0/857.png
#   inflating: __MACOSX/small-mazes/test/0/._857.png
#   inflating: small-mazes/test/0/17.png
#   inflating: __MACOSX/small-mazes/test/0/._17.png
#   inflating: small-mazes/test/0/738.png
#   inflating: __MACOSX/small-mazes/test/0/._738.png
#   inflating: small-mazes/test/0/710.png
#   inflating: __MACOSX/small-mazes/test/0/._710.png
#   inflating: small-mazes/test/0/704.png
#   inflating: __MACOSX/small-mazes/test/0/._704.png
#   inflating: small-mazes/test/0/937.png
#   inflating: __MACOSX/small-mazes/test/0/._937.png
#   inflating: small-mazes/test/0/923.png
#   inflating: __MACOSX/small-mazes/test/0/._923.png
#   inflating: small-mazes/test/0/248.png
#   inflating: __MACOSX/small-mazes/test/0/._248.png
#   inflating: small-mazes/test/0/274.png
#   inflating: __MACOSX/small-mazes/test/0/._274.png
#   inflating: small-mazes/test/0/512.png
#   inflating: __MACOSX/small-mazes/test/0/._512.png
#   inflating: small-mazes/test/0/506.png
#   inflating: __MACOSX/small-mazes/test/0/._506.png
#   inflating: small-mazes/test/0/260.png
#   inflating: __MACOSX/small-mazes/test/0/._260.png
#   inflating: small-mazes/test/0/507.png
#   inflating: __MACOSX/small-mazes/test/0/._507.png
#   inflating: small-mazes/test/0/261.png
#   inflating: __MACOSX/small-mazes/test/0/._261.png
#   inflating: small-mazes/test/0/275.png
#   inflating: __MACOSX/small-mazes/test/0/._275.png
#   inflating: small-mazes/test/0/513.png
#   inflating: __MACOSX/small-mazes/test/0/._513.png
#   inflating: small-mazes/test/0/249.png
#   inflating: __MACOSX/small-mazes/test/0/._249.png
#   inflating: small-mazes/test/0/922.png
#   inflating: __MACOSX/small-mazes/test/0/._922.png
#   inflating: small-mazes/test/0/936.png
#   inflating: __MACOSX/small-mazes/test/0/._936.png
#   inflating: small-mazes/test/0/705.png
#   inflating: __MACOSX/small-mazes/test/0/._705.png
#   inflating: small-mazes/test/0/711.png
#   inflating: __MACOSX/small-mazes/test/0/._711.png
#   inflating: small-mazes/test/0/739.png
#   inflating: __MACOSX/small-mazes/test/0/._739.png
#   inflating: small-mazes/test/0/16.png
#   inflating: __MACOSX/small-mazes/test/0/._16.png
#   inflating: small-mazes/test/0/856.png
#   inflating: __MACOSX/small-mazes/test/0/._856.png
#   inflating: small-mazes/test/0/842.png
#   inflating: __MACOSX/small-mazes/test/0/._842.png
#   inflating: small-mazes/test/0/117.png
#   inflating: __MACOSX/small-mazes/test/0/._117.png
#   inflating: small-mazes/test/0/671.png
#   inflating: __MACOSX/small-mazes/test/0/._671.png
#   inflating: small-mazes/test/0/665.png
#   inflating: __MACOSX/small-mazes/test/0/._665.png
#   inflating: small-mazes/test/0/103.png
#   inflating: __MACOSX/small-mazes/test/0/._103.png
#   inflating: small-mazes/test/0/895.png
#   inflating: __MACOSX/small-mazes/test/0/._895.png
#   inflating: small-mazes/test/0/881.png
#   inflating: __MACOSX/small-mazes/test/0/._881.png
#   inflating: small-mazes/test/0/659.png
#   inflating: __MACOSX/small-mazes/test/0/._659.png
#   inflating: small-mazes/test/0/498.png
#   inflating: __MACOSX/small-mazes/test/0/._498.png
#   inflating: small-mazes/test/0/473.png
#   inflating: __MACOSX/small-mazes/test/0/._473.png
#   inflating: small-mazes/test/0/315.png
#   inflating: __MACOSX/small-mazes/test/0/._315.png
#   inflating: small-mazes/test/0/301.png
#   inflating: __MACOSX/small-mazes/test/0/._301.png
#   inflating: small-mazes/test/0/467.png
#   inflating: __MACOSX/small-mazes/test/0/._467.png
#   inflating: small-mazes/test/0/329.png
#   inflating: __MACOSX/small-mazes/test/0/._329.png
#   inflating: small-mazes/test/0/463.png
#   inflating: __MACOSX/small-mazes/test/0/._463.png
#   inflating: small-mazes/test/0/305.png
#   inflating: __MACOSX/small-mazes/test/0/._305.png
#   inflating: small-mazes/test/0/311.png
#   inflating: __MACOSX/small-mazes/test/0/._311.png
#   inflating: small-mazes/test/0/477.png
#   inflating: __MACOSX/small-mazes/test/0/._477.png
#   inflating: small-mazes/test/0/339.png
#   inflating: __MACOSX/small-mazes/test/0/._339.png
#   inflating: small-mazes/test/0/488.png
#   inflating: __MACOSX/small-mazes/test/0/._488.png
#   inflating: small-mazes/test/0/107.png
#   inflating: __MACOSX/small-mazes/test/0/._107.png
#   inflating: small-mazes/test/0/661.png
#   inflating: __MACOSX/small-mazes/test/0/._661.png
#   inflating: small-mazes/test/0/675.png
#   inflating: __MACOSX/small-mazes/test/0/._675.png
#   inflating: small-mazes/test/0/113.png
#   inflating: __MACOSX/small-mazes/test/0/._113.png
#   inflating: small-mazes/test/0/885.png
#   inflating: __MACOSX/small-mazes/test/0/._885.png
#   inflating: small-mazes/test/0/649.png
#   inflating: __MACOSX/small-mazes/test/0/._649.png
#   inflating: small-mazes/test/0/891.png
#   inflating: __MACOSX/small-mazes/test/0/._891.png
#   inflating: small-mazes/test/0/846.png
#   inflating: __MACOSX/small-mazes/test/0/._846.png
#   inflating: small-mazes/test/0/852.png
#   inflating: __MACOSX/small-mazes/test/0/._852.png
#   inflating: small-mazes/test/0/12.png
#   inflating: __MACOSX/small-mazes/test/0/._12.png
#   inflating: small-mazes/test/0/715.png
#   inflating: __MACOSX/small-mazes/test/0/._715.png
#   inflating: small-mazes/test/0/701.png
#   inflating: __MACOSX/small-mazes/test/0/._701.png
#   inflating: small-mazes/test/0/729.png
#   inflating: __MACOSX/small-mazes/test/0/._729.png
#   inflating: small-mazes/test/0/932.png
#   inflating: __MACOSX/small-mazes/test/0/._932.png
#   inflating: small-mazes/test/0/926.png
#   inflating: __MACOSX/small-mazes/test/0/._926.png
#   inflating: small-mazes/test/0/517.png
#   inflating: __MACOSX/small-mazes/test/0/._517.png
#   inflating: small-mazes/test/0/271.png
#   inflating: __MACOSX/small-mazes/test/0/._271.png
#   inflating: small-mazes/test/0/265.png
#   inflating: __MACOSX/small-mazes/test/0/._265.png
#   inflating: small-mazes/test/0/503.png
#   inflating: __MACOSX/small-mazes/test/0/._503.png
#   inflating: small-mazes/test/0/259.png
#   inflating: __MACOSX/small-mazes/test/0/._259.png
#   inflating: small-mazes/test/0/258.png
#   inflating: __MACOSX/small-mazes/test/0/._258.png
#   inflating: small-mazes/test/0/264.png
#   inflating: __MACOSX/small-mazes/test/0/._264.png
#   inflating: small-mazes/test/0/502.png
#   inflating: __MACOSX/small-mazes/test/0/._502.png
#   inflating: small-mazes/test/0/516.png
#   inflating: __MACOSX/small-mazes/test/0/._516.png
#   inflating: small-mazes/test/0/270.png
#   inflating: __MACOSX/small-mazes/test/0/._270.png
#   inflating: small-mazes/test/0/927.png
#   inflating: __MACOSX/small-mazes/test/0/._927.png
#   inflating: small-mazes/test/0/933.png
#   inflating: __MACOSX/small-mazes/test/0/._933.png
#   inflating: small-mazes/test/0/728.png
#   inflating: __MACOSX/small-mazes/test/0/._728.png
#   inflating: small-mazes/test/0/700.png
#   inflating: __MACOSX/small-mazes/test/0/._700.png
#   inflating: small-mazes/test/0/714.png
#   inflating: __MACOSX/small-mazes/test/0/._714.png
#   inflating: small-mazes/test/0/13.png
#   inflating: __MACOSX/small-mazes/test/0/._13.png
#   inflating: small-mazes/test/0/853.png
#   inflating: __MACOSX/small-mazes/test/0/._853.png
#   inflating: small-mazes/test/0/847.png
#   inflating: __MACOSX/small-mazes/test/0/._847.png
#   inflating: small-mazes/test/0/890.png
#   inflating: __MACOSX/small-mazes/test/0/._890.png
#   inflating: small-mazes/test/0/648.png
#   inflating: __MACOSX/small-mazes/test/0/._648.png
#   inflating: small-mazes/test/0/884.png
#   inflating: __MACOSX/small-mazes/test/0/._884.png
#   inflating: small-mazes/test/0/674.png
#   inflating: __MACOSX/small-mazes/test/0/._674.png
#   inflating: small-mazes/test/0/112.png
#   inflating: __MACOSX/small-mazes/test/0/._112.png
#   inflating: small-mazes/test/0/106.png
#   inflating: __MACOSX/small-mazes/test/0/._106.png
#   inflating: small-mazes/test/0/660.png
#   inflating: __MACOSX/small-mazes/test/0/._660.png
#   inflating: small-mazes/test/0/489.png
#   inflating: __MACOSX/small-mazes/test/0/._489.png
#   inflating: small-mazes/test/0/338.png
#   inflating: __MACOSX/small-mazes/test/0/._338.png
#   inflating: small-mazes/test/0/310.png
#   inflating: __MACOSX/small-mazes/test/0/._310.png
#   inflating: small-mazes/test/0/476.png
#   inflating: __MACOSX/small-mazes/test/0/._476.png
#   inflating: small-mazes/test/0/462.png
#   inflating: __MACOSX/small-mazes/test/0/._462.png
#   inflating: small-mazes/test/0/304.png
#   inflating: __MACOSX/small-mazes/test/0/._304.png
#   inflating: small-mazes/test/0/474.png
#   inflating: __MACOSX/small-mazes/test/0/._474.png
#   inflating: small-mazes/test/0/312.png
#   inflating: __MACOSX/small-mazes/test/0/._312.png
#   inflating: small-mazes/test/0/306.png
#   inflating: __MACOSX/small-mazes/test/0/._306.png
#   inflating: small-mazes/test/0/460.png
#   inflating: __MACOSX/small-mazes/test/0/._460.png
#   inflating: small-mazes/test/0/448.png
#   inflating: __MACOSX/small-mazes/test/0/._448.png
#   inflating: small-mazes/test/0/110.png
#   inflating: __MACOSX/small-mazes/test/0/._110.png
#   inflating: small-mazes/test/0/676.png
#   inflating: __MACOSX/small-mazes/test/0/._676.png
#   inflating: small-mazes/test/0/662.png
#   inflating: __MACOSX/small-mazes/test/0/._662.png
#   inflating: small-mazes/test/0/104.png
#   inflating: __MACOSX/small-mazes/test/0/._104.png
#   inflating: small-mazes/test/0/892.png
#   inflating: __MACOSX/small-mazes/test/0/._892.png
#   inflating: small-mazes/test/0/886.png
#   inflating: __MACOSX/small-mazes/test/0/._886.png
#   inflating: small-mazes/test/0/138.png
#   inflating: __MACOSX/small-mazes/test/0/._138.png
#   inflating: small-mazes/test/0/879.png
#   inflating: __MACOSX/small-mazes/test/0/._879.png
#   inflating: small-mazes/test/0/39.png
#   inflating: __MACOSX/small-mazes/test/0/._39.png
#   inflating: small-mazes/test/0/851.png
#   inflating: __MACOSX/small-mazes/test/0/._851.png
#   inflating: small-mazes/test/0/689.png
#   inflating: __MACOSX/small-mazes/test/0/._689.png
#   inflating: small-mazes/test/0/11.png
#   inflating: __MACOSX/small-mazes/test/0/._11.png
#   inflating: small-mazes/test/0/845.png
#   inflating: __MACOSX/small-mazes/test/0/._845.png
#   inflating: small-mazes/test/0/702.png
#   inflating: __MACOSX/small-mazes/test/0/._702.png
#   inflating: small-mazes/test/0/716.png
#   inflating: __MACOSX/small-mazes/test/0/._716.png
#   inflating: small-mazes/test/0/919.png
#   inflating: __MACOSX/small-mazes/test/0/._919.png
#   inflating: small-mazes/test/0/925.png
#   inflating: __MACOSX/small-mazes/test/0/._925.png
#   inflating: small-mazes/test/0/931.png
#   inflating: __MACOSX/small-mazes/test/0/._931.png
#   inflating: small-mazes/test/0/500.png
#   inflating: __MACOSX/small-mazes/test/0/._500.png
#   inflating: small-mazes/test/0/266.png
#   inflating: __MACOSX/small-mazes/test/0/._266.png
#   inflating: small-mazes/test/0/272.png
#   inflating: __MACOSX/small-mazes/test/0/._272.png
#   inflating: small-mazes/test/0/514.png
#   inflating: __MACOSX/small-mazes/test/0/._514.png
#   inflating: small-mazes/test/0/528.png
#   inflating: __MACOSX/small-mazes/test/0/._528.png
#   inflating: small-mazes/test/0/299.png
#   inflating: __MACOSX/small-mazes/test/0/._299.png
#   inflating: small-mazes/test/0/298.png
#   inflating: __MACOSX/small-mazes/test/0/._298.png
#   inflating: small-mazes/test/0/529.png
#   inflating: __MACOSX/small-mazes/test/0/._529.png
#   inflating: small-mazes/test/0/273.png
#   inflating: __MACOSX/small-mazes/test/0/._273.png
#   inflating: small-mazes/test/0/515.png
#   inflating: __MACOSX/small-mazes/test/0/._515.png
#   inflating: small-mazes/test/0/501.png
#   inflating: __MACOSX/small-mazes/test/0/._501.png
#   inflating: small-mazes/test/0/267.png
#   inflating: __MACOSX/small-mazes/test/0/._267.png
#   inflating: small-mazes/test/0/930.png
#   inflating: __MACOSX/small-mazes/test/0/._930.png
#   inflating: small-mazes/test/0/924.png
#   inflating: __MACOSX/small-mazes/test/0/._924.png
#   inflating: small-mazes/test/0/918.png
#   inflating: __MACOSX/small-mazes/test/0/._918.png
#   inflating: small-mazes/test/0/717.png
#   inflating: __MACOSX/small-mazes/test/0/._717.png
#   inflating: small-mazes/test/0/703.png
#   inflating: __MACOSX/small-mazes/test/0/._703.png
#   inflating: small-mazes/test/0/844.png
#   inflating: __MACOSX/small-mazes/test/0/._844.png
#   inflating: small-mazes/test/0/10.png
#   inflating: __MACOSX/small-mazes/test/0/._10.png
#   inflating: small-mazes/test/0/688.png
#   inflating: __MACOSX/small-mazes/test/0/._688.png
#   inflating: small-mazes/test/0/850.png
#   inflating: __MACOSX/small-mazes/test/0/._850.png
#   inflating: small-mazes/test/0/38.png
#   inflating: __MACOSX/small-mazes/test/0/._38.png
#   inflating: small-mazes/test/0/878.png
#   inflating: __MACOSX/small-mazes/test/0/._878.png
#   inflating: small-mazes/test/0/887.png
#   inflating: __MACOSX/small-mazes/test/0/._887.png
#   inflating: small-mazes/test/0/139.png
#   inflating: __MACOSX/small-mazes/test/0/._139.png
#   inflating: small-mazes/test/0/893.png
#   inflating: __MACOSX/small-mazes/test/0/._893.png
#   inflating: small-mazes/test/0/663.png
#   inflating: __MACOSX/small-mazes/test/0/._663.png
#   inflating: small-mazes/test/0/105.png
#   inflating: __MACOSX/small-mazes/test/0/._105.png
#   inflating: small-mazes/test/0/111.png
#   inflating: __MACOSX/small-mazes/test/0/._111.png
#   inflating: small-mazes/test/0/677.png
#   inflating: __MACOSX/small-mazes/test/0/._677.png
#   inflating: small-mazes/test/0/449.png
#   inflating: __MACOSX/small-mazes/test/0/._449.png
#   inflating: small-mazes/test/0/307.png
#   inflating: __MACOSX/small-mazes/test/0/._307.png
#   inflating: small-mazes/test/0/461.png
#   inflating: __MACOSX/small-mazes/test/0/._461.png
#   inflating: small-mazes/test/0/475.png
#   inflating: __MACOSX/small-mazes/test/0/._475.png
#   inflating: small-mazes/test/0/313.png
#   inflating: __MACOSX/small-mazes/test/0/._313.png
#   inflating: small-mazes/test/0/478.png
#   inflating: __MACOSX/small-mazes/test/0/._478.png
#   inflating: small-mazes/test/0/336.png
#   inflating: __MACOSX/small-mazes/test/0/._336.png
#   inflating: small-mazes/test/0/450.png
#   inflating: __MACOSX/small-mazes/test/0/._450.png
#   inflating: small-mazes/test/0/444.png
#   inflating: __MACOSX/small-mazes/test/0/._444.png
#   inflating: small-mazes/test/0/322.png
#   inflating: __MACOSX/small-mazes/test/0/._322.png
#   inflating: small-mazes/test/0/493.png
#   inflating: __MACOSX/small-mazes/test/0/._493.png
#   inflating: small-mazes/test/0/487.png
#   inflating: __MACOSX/small-mazes/test/0/._487.png
#   inflating: small-mazes/test/0/108.png
#   inflating: __MACOSX/small-mazes/test/0/._108.png
#   inflating: small-mazes/test/0/652.png
#   inflating: __MACOSX/small-mazes/test/0/._652.png
#   inflating: small-mazes/test/0/134.png
#   inflating: __MACOSX/small-mazes/test/0/._134.png
#   inflating: small-mazes/test/0/120.png
#   inflating: __MACOSX/small-mazes/test/0/._120.png
#   inflating: small-mazes/test/0/646.png
#   inflating: __MACOSX/small-mazes/test/0/._646.png
#   inflating: small-mazes/test/0/875.png
#   inflating: __MACOSX/small-mazes/test/0/._875.png
#   inflating: small-mazes/test/0/35.png
#   inflating: __MACOSX/small-mazes/test/0/._35.png
#   inflating: small-mazes/test/0/861.png
#   inflating: __MACOSX/small-mazes/test/0/._861.png
#   inflating: small-mazes/test/0/21.png
#   inflating: __MACOSX/small-mazes/test/0/._21.png
#   inflating: small-mazes/test/0/849.png
#   inflating: __MACOSX/small-mazes/test/0/._849.png
#   inflating: small-mazes/test/0/691.png
#   inflating: __MACOSX/small-mazes/test/0/._691.png
#   inflating: small-mazes/test/0/685.png
#   inflating: __MACOSX/small-mazes/test/0/._685.png
#   inflating: small-mazes/test/0/726.png
#   inflating: __MACOSX/small-mazes/test/0/._726.png
#   inflating: small-mazes/test/0/732.png
#   inflating: __MACOSX/small-mazes/test/0/._732.png
#   inflating: small-mazes/test/0/901.png
#   inflating: __MACOSX/small-mazes/test/0/._901.png
#   inflating: small-mazes/test/0/915.png
#   inflating: __MACOSX/small-mazes/test/0/._915.png
#   inflating: small-mazes/test/0/929.png
#   inflating: __MACOSX/small-mazes/test/0/._929.png
#   inflating: small-mazes/test/0/518.png
#   inflating: __MACOSX/small-mazes/test/0/._518.png
#   inflating: small-mazes/test/0/242.png
#   inflating: __MACOSX/small-mazes/test/0/._242.png
#   inflating: small-mazes/test/0/524.png
#   inflating: __MACOSX/small-mazes/test/0/._524.png
#   inflating: small-mazes/test/0/530.png
#   inflating: __MACOSX/small-mazes/test/0/._530.png
#   inflating: small-mazes/test/0/256.png
#   inflating: __MACOSX/small-mazes/test/0/._256.png
#   inflating: small-mazes/test/0/281.png
#   inflating: __MACOSX/small-mazes/test/0/._281.png
#   inflating: small-mazes/test/0/295.png
#   inflating: __MACOSX/small-mazes/test/0/._295.png
#   inflating: small-mazes/test/0/294.png
#   inflating: __MACOSX/small-mazes/test/0/._294.png
#   inflating: small-mazes/test/0/280.png
#   inflating: __MACOSX/small-mazes/test/0/._280.png
#   inflating: small-mazes/test/0/531.png
#   inflating: __MACOSX/small-mazes/test/0/._531.png
#   inflating: small-mazes/test/0/257.png
#   inflating: __MACOSX/small-mazes/test/0/._257.png
#   inflating: small-mazes/test/0/243.png
#   inflating: __MACOSX/small-mazes/test/0/._243.png
#   inflating: small-mazes/test/0/525.png
#   inflating: __MACOSX/small-mazes/test/0/._525.png
#   inflating: small-mazes/test/0/519.png
#   inflating: __MACOSX/small-mazes/test/0/._519.png
#   inflating: small-mazes/test/0/928.png
#   inflating: __MACOSX/small-mazes/test/0/._928.png
#   inflating: small-mazes/test/0/914.png
# ...
#   inflating: small-mazes/train/0/4391.png
#   inflating: __MACOSX/small-mazes/train/0/._4391.png
#   inflating: small-mazes/train/0/2086.png
#   inflating: __MACOSX/small-mazes/train/0/._2086.png
#   inflating: small-mazes/train/0/3398.png
#   inflating: __MACOSX/small-mazes/train/0/._3398.png
#   inflating: small-mazes/train/0/5931.png
#   inflating: __MACOSX/small-mazes/train/0/._5931.png
#   inflating: small-mazes/train/0/5919.png
#   inflating: __MACOSX/small-mazes/train/0/._5919.png
#   inflating: small-mazes/train/0/755.png
#   inflating: __MACOSX/small-mazes/train/0/._755.png
#   inflating: small-mazes/train/0/7868.png
#   inflating: __MACOSX/small-mazes/train/0/._7868.png
#   inflating: small-mazes/train/0/8583.png
#   inflating: __MACOSX/small-mazes/train/0/._8583.png
#   inflating: small-mazes/train/0/2910.png
#   inflating: __MACOSX/small-mazes/train/0/._2910.png
#   inflating: small-mazes/train/0/2904.png
#   inflating: __MACOSX/small-mazes/train/0/._2904.png
#   inflating: small-mazes/train/0/741.png
#   inflating: __MACOSX/small-mazes/train/0/._741.png
#   inflating: small-mazes/train/0/999.png
#   inflating: __MACOSX/small-mazes/train/0/._999.png
#   inflating: small-mazes/train/0/8597.png
#   inflating: __MACOSX/small-mazes/train/0/._8597.png
#   inflating: small-mazes/train/0/2125.png
#   inflating: __MACOSX/small-mazes/train/0/._2125.png
#   inflating: small-mazes/train/0/5892.png
#   inflating: __MACOSX/small-mazes/train/0/._5892.png
#   inflating: small-mazes/train/0/4554.png
#   inflating: __MACOSX/small-mazes/train/0/._4554.png
#   inflating: small-mazes/train/0/6343.png
#   inflating: __MACOSX/small-mazes/train/0/._6343.png
#   inflating: small-mazes/train/0/6425.png
#   inflating: __MACOSX/small-mazes/train/0/._6425.png
#   inflating: small-mazes/train/0/46.png
#   inflating: __MACOSX/small-mazes/train/0/._46.png
#   inflating: small-mazes/train/0/8408.png
#   inflating: __MACOSX/small-mazes/train/0/._8408.png
#   inflating: small-mazes/train/0/806.png
#   inflating: __MACOSX/small-mazes/train/0/._806.png
#   inflating: small-mazes/train/0/4232.png
#   inflating: __MACOSX/small-mazes/train/0/._4232.png
#   inflating: small-mazes/train/0/2643.png
#   inflating: __MACOSX/small-mazes/train/0/._2643.png
#   inflating: small-mazes/train/0/4226.png
#   inflating: __MACOSX/small-mazes/train/0/._4226.png
#   inflating: small-mazes/train/0/3549.png
#   inflating: __MACOSX/small-mazes/train/0/._3549.png
#   inflating: small-mazes/train/0/2657.png
#   inflating: __MACOSX/small-mazes/train/0/._2657.png
#   inflating: small-mazes/train/0/5138.png
#   inflating: __MACOSX/small-mazes/train/0/._5138.png
#   inflating: small-mazes/train/0/52.png
#   inflating: __MACOSX/small-mazes/train/0/._52.png
#   inflating: small-mazes/train/0/6431.png
#   inflating: __MACOSX/small-mazes/train/0/._6431.png
#   inflating: small-mazes/train/0/812.png
#   inflating: __MACOSX/small-mazes/train/0/._812.png
#   inflating: small-mazes/train/0/7049.png
#   inflating: __MACOSX/small-mazes/train/0/._7049.png
#   inflating: small-mazes/train/0/1438.png
#   inflating: __MACOSX/small-mazes/train/0/._1438.png
#   inflating: small-mazes/train/0/6357.png
#   inflating: __MACOSX/small-mazes/train/0/._6357.png
#   inflating: small-mazes/train/0/2131.png
#   inflating: __MACOSX/small-mazes/train/0/._2131.png
#   inflating: small-mazes/train/0/5886.png
#   inflating: __MACOSX/small-mazes/train/0/._5886.png
#   inflating: small-mazes/train/0/0.png
#   inflating: __MACOSX/small-mazes/train/0/._0.png
#   inflating: small-mazes/train/0/4540.png
#   inflating: __MACOSX/small-mazes/train/0/._4540.png
#   inflating: small-mazes/train/0/8352.png
#   inflating: __MACOSX/small-mazes/train/0/._8352.png
#   inflating: small-mazes/train/0/7061.png
#   inflating: __MACOSX/small-mazes/train/0/._7061.png
#   inflating: small-mazes/train/0/1410.png
#   inflating: __MACOSX/small-mazes/train/0/._1410.png
#   inflating: small-mazes/train/0/184.png
#   inflating: __MACOSX/small-mazes/train/0/._184.png
#   inflating: small-mazes/train/0/5676.png
#   inflating: __MACOSX/small-mazes/train/0/._5676.png
#   inflating: small-mazes/train/0/2119.png
#   inflating: __MACOSX/small-mazes/train/0/._2119.png
#   inflating: small-mazes/train/0/3207.png
#   inflating: __MACOSX/small-mazes/train/0/._3207.png
#   inflating: small-mazes/train/0/4568.png
#   inflating: __MACOSX/small-mazes/train/0/._4568.png
#   inflating: small-mazes/train/0/3561.png
#   inflating: __MACOSX/small-mazes/train/0/._3561.png
#   inflating: small-mazes/train/0/5110.png
#   inflating: __MACOSX/small-mazes/train/0/._5110.png
#   inflating: small-mazes/train/0/6419.png
#   inflating: __MACOSX/small-mazes/train/0/._6419.png
#   inflating: small-mazes/train/0/1376.png
#   inflating: __MACOSX/small-mazes/train/0/._1376.png
#   inflating: small-mazes/train/0/8434.png
#   inflating: __MACOSX/small-mazes/train/0/._8434.png
#   inflating: small-mazes/train/0/7707.png
#   inflating: __MACOSX/small-mazes/train/0/._7707.png
#   inflating: small-mazes/train/0/1362.png
#   inflating: __MACOSX/small-mazes/train/0/._1362.png
#   inflating: small-mazes/train/0/8420.png
#   inflating: __MACOSX/small-mazes/train/0/._8420.png
#   inflating: small-mazes/train/0/7713.png
#   inflating: __MACOSX/small-mazes/train/0/._7713.png
#   inflating: small-mazes/train/0/3575.png
#   inflating: __MACOSX/small-mazes/train/0/._3575.png
#   inflating: small-mazes/train/0/5104.png
#   inflating: __MACOSX/small-mazes/train/0/._5104.png
#   inflating: small-mazes/train/0/5662.png
#   inflating: __MACOSX/small-mazes/train/0/._5662.png
#   inflating: small-mazes/train/0/3213.png
#   inflating: __MACOSX/small-mazes/train/0/._3213.png
#   inflating: small-mazes/train/0/8346.png
#   inflating: __MACOSX/small-mazes/train/0/._8346.png
#   inflating: small-mazes/train/0/7075.png
#   inflating: __MACOSX/small-mazes/train/0/._7075.png
#   inflating: small-mazes/train/0/190.png
#   inflating: __MACOSX/small-mazes/train/0/._190.png
#   inflating: small-mazes/train/0/1404.png
#   inflating: __MACOSX/small-mazes/train/0/._1404.png
#   inflating: small-mazes/train/0/6380.png
#   inflating: __MACOSX/small-mazes/train/0/._6380.png
#   inflating: small-mazes/train/0/5851.png
#   inflating: __MACOSX/small-mazes/train/0/._5851.png
#   inflating: small-mazes/train/0/4597.png
#   inflating: __MACOSX/small-mazes/train/0/._4597.png
#   inflating: small-mazes/train/0/5689.png
#   inflating: __MACOSX/small-mazes/train/0/._5689.png
#   inflating: small-mazes/train/0/2680.png
#   inflating: __MACOSX/small-mazes/train/0/._2680.png
#   inflating: small-mazes/train/0/2858.png
#   inflating: __MACOSX/small-mazes/train/0/._2858.png
#   inflating: small-mazes/train/0/85.png
#   inflating: __MACOSX/small-mazes/train/0/._85.png
#   inflating: small-mazes/train/0/7920.png
#   inflating: __MACOSX/small-mazes/train/0/._7920.png
#   inflating: small-mazes/train/0/1389.png
#   inflating: __MACOSX/small-mazes/train/0/._1389.png
#   inflating: small-mazes/train/0/91.png
#   inflating: __MACOSX/small-mazes/train/0/._91.png
#   inflating: small-mazes/train/0/7934.png
#   inflating: __MACOSX/small-mazes/train/0/._7934.png
#   inflating: small-mazes/train/0/609.png
#   inflating: __MACOSX/small-mazes/train/0/._609.png
#   inflating: small-mazes/train/0/2694.png
#   inflating: __MACOSX/small-mazes/train/0/._2694.png
#   inflating: small-mazes/train/0/5845.png
#   inflating: __MACOSX/small-mazes/train/0/._5845.png
#   inflating: small-mazes/train/0/4583.png
#   inflating: __MACOSX/small-mazes/train/0/._4583.png
#   inflating: small-mazes/train/0/6394.png
#   inflating: __MACOSX/small-mazes/train/0/._6394.png
#   inflating: small-mazes/train/0/147.png
#   inflating: __MACOSX/small-mazes/train/0/._147.png
#   inflating: small-mazes/train/0/8391.png
#   inflating: __MACOSX/small-mazes/train/0/._8391.png
#   inflating: small-mazes/train/0/621.png
#   inflating: __MACOSX/small-mazes/train/0/._621.png
#   inflating: small-mazes/train/0/2864.png
#   inflating: __MACOSX/small-mazes/train/0/._2864.png
#   inflating: small-mazes/train/0/2870.png
#   inflating: __MACOSX/small-mazes/train/0/._2870.png
#   inflating: small-mazes/train/0/635.png
#   inflating: __MACOSX/small-mazes/train/0/._635.png
#   inflating: small-mazes/train/0/7908.png
#   inflating: __MACOSX/small-mazes/train/0/._7908.png
#   inflating: small-mazes/train/0/153.png
#   inflating: __MACOSX/small-mazes/train/0/._153.png
#   inflating: small-mazes/train/0/8385.png
#   inflating: __MACOSX/small-mazes/train/0/._8385.png
#   inflating: small-mazes/train/0/5879.png
#   inflating: __MACOSX/small-mazes/train/0/._5879.png
#   inflating: small-mazes/train/0/3987.png
#   inflating: __MACOSX/small-mazes/train/0/._3987.png
#   inflating: small-mazes/train/0/2441.png
#   inflating: __MACOSX/small-mazes/train/0/._2441.png
#   inflating: small-mazes/train/0/4030.png
#   inflating: __MACOSX/small-mazes/train/0/._4030.png
#   inflating: small-mazes/train/0/7539.png
#   inflating: __MACOSX/small-mazes/train/0/._7539.png
#   inflating: small-mazes/train/0/1148.png
#   inflating: __MACOSX/small-mazes/train/0/._1148.png
#   inflating: small-mazes/train/0/6627.png
#   inflating: __MACOSX/small-mazes/train/0/._6627.png
#   inflating: small-mazes/train/0/6141.png
#   inflating: __MACOSX/small-mazes/train/0/._6141.png
#   inflating: small-mazes/train/0/4756.png
#   inflating: __MACOSX/small-mazes/train/0/._4756.png
#   inflating: small-mazes/train/0/3039.png
#   inflating: __MACOSX/small-mazes/train/0/._3039.png
#   inflating: small-mazes/train/0/2327.png
#   inflating: __MACOSX/small-mazes/train/0/._2327.png
#   inflating: small-mazes/train/0/5448.png
#   inflating: __MACOSX/small-mazes/train/0/._5448.png
#   inflating: small-mazes/train/0/4742.png
#   inflating: __MACOSX/small-mazes/train/0/._4742.png
#   inflating: small-mazes/train/0/2333.png
#   inflating: __MACOSX/small-mazes/train/0/._2333.png
#   inflating: small-mazes/train/0/6155.png
#   inflating: __MACOSX/small-mazes/train/0/._6155.png
#   inflating: small-mazes/train/0/8178.png
#   inflating: __MACOSX/small-mazes/train/0/._8178.png
#   inflating: small-mazes/train/0/6633.png
#   inflating: __MACOSX/small-mazes/train/0/._6633.png
#   inflating: small-mazes/train/0/3993.png
#   inflating: __MACOSX/small-mazes/train/0/._3993.png
#   inflating: small-mazes/train/0/2455.png
#   inflating: __MACOSX/small-mazes/train/0/._2455.png
#   inflating: small-mazes/train/0/4024.png
#   inflating: __MACOSX/small-mazes/train/0/._4024.png
#   inflating: small-mazes/train/0/7505.png
#   inflating: __MACOSX/small-mazes/train/0/._7505.png
#   inflating: small-mazes/train/0/8636.png
#   inflating: __MACOSX/small-mazes/train/0/._8636.png
#   inflating: small-mazes/train/0/1174.png
#   inflating: __MACOSX/small-mazes/train/0/._1174.png
#   inflating: small-mazes/train/0/5312.png
#   inflating: __MACOSX/small-mazes/train/0/._5312.png
#   inflating: small-mazes/train/0/3763.png
#   inflating: __MACOSX/small-mazes/train/0/._3763.png
#   inflating: small-mazes/train/0/3005.png
#   inflating: __MACOSX/small-mazes/train/0/._3005.png
#   inflating: small-mazes/train/0/5474.png
#   inflating: __MACOSX/small-mazes/train/0/._5474.png
#   inflating: small-mazes/train/0/386.png
#   inflating: __MACOSX/small-mazes/train/0/._386.png
#   inflating: small-mazes/train/0/1612.png
#   inflating: __MACOSX/small-mazes/train/0/._1612.png
#   inflating: small-mazes/train/0/7263.png
#   inflating: __MACOSX/small-mazes/train/0/._7263.png
#   inflating: small-mazes/train/0/8150.png
#   inflating: __MACOSX/small-mazes/train/0/._8150.png
#   inflating: small-mazes/train/0/6169.png
#   inflating: __MACOSX/small-mazes/train/0/._6169.png
#   inflating: small-mazes/train/0/1606.png
#   inflating: __MACOSX/small-mazes/train/0/._1606.png
#   inflating: small-mazes/train/0/392.png
#   inflating: __MACOSX/small-mazes/train/0/._392.png
#   inflating: small-mazes/train/0/7277.png
#   inflating: __MACOSX/small-mazes/train/0/._7277.png
#   inflating: small-mazes/train/0/8144.png
#   inflating: __MACOSX/small-mazes/train/0/._8144.png
#   inflating: small-mazes/train/0/3011.png
#   inflating: __MACOSX/small-mazes/train/0/._3011.png
#   inflating: small-mazes/train/0/5460.png
#   inflating: __MACOSX/small-mazes/train/0/._5460.png
#   inflating: small-mazes/train/0/5306.png
#   inflating: __MACOSX/small-mazes/train/0/._5306.png
#   inflating: small-mazes/train/0/2469.png
#   inflating: __MACOSX/small-mazes/train/0/._2469.png
#   inflating: small-mazes/train/0/3777.png
#   inflating: __MACOSX/small-mazes/train/0/._3777.png
#   inflating: small-mazes/train/0/4018.png
#   inflating: __MACOSX/small-mazes/train/0/._4018.png
#   inflating: small-mazes/train/0/7511.png
#   inflating: __MACOSX/small-mazes/train/0/._7511.png
#   inflating: small-mazes/train/0/8622.png
#   inflating: __MACOSX/small-mazes/train/0/._8622.png
#   inflating: small-mazes/train/0/1160.png
#   inflating: __MACOSX/small-mazes/train/0/._1160.png
#   inflating: small-mazes/train/0/8811.png
#   inflating: __MACOSX/small-mazes/train/0/._8811.png
#   inflating: small-mazes/train/0/3944.png
#   inflating: __MACOSX/small-mazes/train/0/._3944.png
#   inflating: small-mazes/train/0/2482.png
#   inflating: __MACOSX/small-mazes/train/0/._2482.png
#   inflating: small-mazes/train/0/4795.png
#   inflating: __MACOSX/small-mazes/train/0/._4795.png
#   inflating: small-mazes/train/0/1835.png
#   inflating: __MACOSX/small-mazes/train/0/._1835.png
#   inflating: small-mazes/train/0/6182.png
#   inflating: __MACOSX/small-mazes/train/0/._6182.png
#   inflating: small-mazes/train/0/379.png
#   inflating: __MACOSX/small-mazes/train/0/._379.png
#   inflating: small-mazes/train/0/1821.png
#   inflating: __MACOSX/small-mazes/train/0/._1821.png
#   inflating: small-mazes/train/0/7288.png
#   inflating: __MACOSX/small-mazes/train/0/._7288.png
#   inflating: small-mazes/train/0/6196.png
#   inflating: __MACOSX/small-mazes/train/0/._6196.png
#   inflating: small-mazes/train/0/4959.png
#   inflating: __MACOSX/small-mazes/train/0/._4959.png
#   inflating: small-mazes/train/0/4781.png
#   inflating: __MACOSX/small-mazes/train/0/._4781.png
#   inflating: small-mazes/train/0/3788.png
#   inflating: __MACOSX/small-mazes/train/0/._3788.png
#   inflating: small-mazes/train/0/3950.png
#   inflating: __MACOSX/small-mazes/train/0/._3950.png
#   inflating: small-mazes/train/0/2496.png
#   inflating: __MACOSX/small-mazes/train/0/._2496.png
#   inflating: small-mazes/train/0/8805.png
#   inflating: __MACOSX/small-mazes/train/0/._8805.png
#   inflating: small-mazes/train/0/6828.png
#   inflating: __MACOSX/small-mazes/train/0/._6828.png
#   inflating: small-mazes/train/0/3978.png
#   inflating: __MACOSX/small-mazes/train/0/._3978.png
#   inflating: small-mazes/train/0/423.png
#   inflating: __MACOSX/small-mazes/train/0/._423.png
#   inflating: small-mazes/train/0/6800.png
#   inflating: __MACOSX/small-mazes/train/0/._6800.png
#   inflating: small-mazes/train/0/8193.png
#   inflating: __MACOSX/small-mazes/train/0/._8193.png
#   inflating: small-mazes/train/0/1809.png
#   inflating: __MACOSX/small-mazes/train/0/._1809.png
#   inflating: small-mazes/train/0/345.png
#   inflating: __MACOSX/small-mazes/train/0/._345.png
#   inflating: small-mazes/train/0/4971.png
#   inflating: __MACOSX/small-mazes/train/0/._4971.png
#   inflating: small-mazes/train/0/4965.png
#   inflating: __MACOSX/small-mazes/train/0/._4965.png
#   inflating: small-mazes/train/0/8187.png
#   inflating: __MACOSX/small-mazes/train/0/._8187.png
#   inflating: small-mazes/train/0/351.png
#   inflating: __MACOSX/small-mazes/train/0/._351.png
#   inflating: small-mazes/train/0/437.png
#   inflating: __MACOSX/small-mazes/train/0/._437.png
#   inflating: small-mazes/train/0/8839.png
#   inflating: __MACOSX/small-mazes/train/0/._8839.png
#   inflating: small-mazes/train/0/6814.png
#   inflating: __MACOSX/small-mazes/train/0/._6814.png

# %% [markdown]
# Imports

# %%
import os
import torch
import torch.nn as nn
import numpy as np
import random
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
from PIL import Image
import imageio
import mediapy
import re

from models.ctm import ContinuousThoughtMachine as CTM
from data.custom_datasets import MazeImageFolder
from tasks.mazes.plotting import make_maze_gif
from tasks.image_classification.plotting import plot_neural_dynamics

# %%
# %matplotlib inline

# %% [markdown]
# Set a seed for reproducibility

# %%
def set_seed(seed=42, deterministic=True):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = deterministic
    torch.backends.cudnn.benchmark = False

# %%
set_seed(42)

# %% [markdown]
# ### Data

# %% [markdown]
# The training (test) folder contains roughly 9000 (1000) images of mazes, at a resolution of 15x15. In these images, the red and green pixels correspond to the start and goal position respectively, while the blue pixels indicate the path through the maze. We will use these blue pixels to construct targets, and remove them from the images.

# %%
data_root = './small-mazes'
train_dir = f"{data_root}/train/0"
images = os.listdir(train_dir)[:4]

plt.figure(figsize=(6, 6))
for i, img_name in enumerate(images):
    img = Image.open(f"{data_root}/train/0/{img_name}")
    plt.subplot(2, 2, i + 1)
    plt.imshow(img)
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# To use these mazes, we have built a custom dataset `MazeImageFolder`. This dataset creates the input-target pairs corresponding to the unsolved mazes images and their solutions. For more details on how this dataset processes the images, please refer to its implementation [here](https://github.com/SakanaAI/continuous-thought-machines/blob/aecfb63ac42db7a20903ee27489ff71671669474/data/custom_datasets.py#L142C7-L142C22).
#
# Note that the `MazeImageFolder` takes a `maze_route_length` argument. This parameter specifies the fixed length of action sequences that the CTM will generate at each internal tick. Since different mazes have solutions of varying lengths, all target sequences are padded with the integer 4 (corresponding to a wait or no operation) to ensure they match the specified `maze_route_length`.

# %%
train_data = MazeImageFolder(root=f'{data_root}/train/', which_set='train', maze_route_length=50)
test_data = MazeImageFolder(root=f'{data_root}/test/', which_set='test', maze_route_length=50)

trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True, num_workers=0, drop_last=True)
testloader = torch.utils.data.DataLoader(test_data, batch_size=64, shuffle=True, num_workers=1, drop_last=True)
# Out:
#   0%|          | 0/9000 [00:00<?, ?it/s]
# Solving all mazes...
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Solving all mazes...

# %% [markdown]
# We can visualise what these inputs and targets look like.

# %%
sample_inputs, sample_targets = next(iter(testloader))
sample_input, sample_target = sample_inputs[0], sample_targets[0]
sample_input = sample_input.permute(1, 2, 0).numpy()
plt.figure(figsize=(6, 6))
plt.imshow(np.clip(sample_input, 0, 1))
plt.axis('off')
plt.show()

print("Target action sequence:")
print(f"{sample_target.tolist()}")
# Out:
# Target action sequence:
# [1, 1, 2, 2, 0, 0, 0, 0, 2, 2, 2, 2, 0, 0, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]

# %% [markdown]
# As shown in the above output, the target is a sequence of integers, each corresponding to an action:
#   - 0: Up
#   - 1: Down
#   - 2: Left
#   - 3: Right
#   - 4: No Operation / Padding
#
# Note that the target sequence has been padded with 4s to achieve the desired length of `maze_route_length`.

# %% [markdown]
# Let's also plot the distribution of maze lengths. We can see that the mode of the distribution is 50, corresponding to us slicing trajectories beyond the `maze_route_length=50` action.

# %%
all_lengths = []
for _, targets in testloader:
    for target in targets:
        length = (target != 4).sum().item()
        all_lengths.append(length)

# Plot histogram
plt.figure(figsize=(6, 4))
plt.hist(all_lengths, bins=20, edgecolor='black')
plt.title("Distribution of Maze Path Lengths")
plt.xlabel("Path Length (upto 50 steps)")
plt.ylabel("Frequency")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Loss Function

# %% [markdown]
# Next, we define the loss function. We use the cross-entropy loss but there are two main points to highlight:
#
# 1) Although we compute the loss at all internal ticks, we only use include in the final loss the value at **two specific internal ticks**. These correspond to the internal tick which achieved the lowest cross-entropy loss of all internal ticks (`loss_index_1` below), and the internal tick at which the model has the highest certainty (`loss_index_2` below). Becaues these indices will vary across batch elements we define a `batch_indexer` which we can use for advanced indexing into the `losses` tensor which stores the loss at all internal ticks.
#
# 2) Our loss calculation uses an auto-extending cirriculum. Specifically, for each trajectory (recall the CTM produces an entire trajectory for every internal tick), we find the index of the first action that the CTM got wrong, and then **only include in our loss the trajectory up to and extending `cirriculum_lookahead` actions beyond this first incorrect action**. In this way, the CTM initially focuses on correctly predicting the first actions, and as it learns, it gets better at producing later and later actions.

# %%
def maze_loss(predictions, certainties, targets, cirriculum_lookahead=5, use_most_certain=True):
    """
    Computes the maze loss with auto-extending cirriculum.

    Predictions are of shape: (B, route_length, class, internal_ticks),
        where classes are in [0,1,2,3,4] for [Up, Down, Left, Right, Wait]
    Certainties are of shape: (B, 2, internal_ticks), 
        where the inside dimension (2) is [normalised_entropy, 1-normalised_entropy]
    Targets are of shape: [B, route_length]

    cirriculum_lookahead: how far to look ahead in the auto-cirriculum

    use_most_certain will select either the most certain point or the final point. For baselines,
        the final point proved the only usable option. 
    
    """
    # Predictions reshaped to: [B*route_length, 5, internal_ticks]
    predictions_reshaped = predictions.flatten(0,1)
    # Targets reshaped to: [B*route_length, internal_ticks]
    targets_reshaped = torch.repeat_interleave(targets.unsqueeze(-1), 
                                               predictions.size(-1), -1).flatten(0,1).long()
    
    # Losses are of shape [B, route_length, internal_ticks]
    losses = nn.CrossEntropyLoss(reduction='none')(predictions_reshaped, targets_reshaped)
    losses = losses.reshape(predictions[:,:,0].shape)
    
    # Below is the code for auto-cirriculum
    # Find where correct, and make sure to always push +5 beyond that
    iscorrects = (predictions.argmax(2) == targets.unsqueeze(-1)).cumsum(1)
    correct_mask = (iscorrects == torch.arange(1, iscorrects.size(1)+1, device=iscorrects.device).reshape(1, -1, 1))
    correct_mask[:,0,:] = 1
    upto_where = correct_mask.cumsum(1).argmax(1).max(-1)[0]+cirriculum_lookahead
    loss_mask = torch.zeros_like(losses)
    for bi in range(predictions.size(0)):
        loss_mask[bi, :upto_where[bi]] = 1

    # Reduce losses along route dimension
    # Will now be of shape [B, internal_ticks]
    losses = (losses * loss_mask).sum(1)/(loss_mask.sum(1))

    loss_index_1 = losses.argmin(dim=1)
    loss_index_2 = certainties[:,1].argmax(-1)
    if not use_most_certain:
        loss_index_2[:] = -1
    
    batch_indexer = torch.arange(predictions.size(0), device=predictions.device)
    loss_minimum_ce = losses[batch_indexer, loss_index_1]
    loss_selected = losses[batch_indexer, loss_index_2]

    loss = ((loss_minimum_ce + loss_selected)/2).mean()
    return loss, loss_index_2, upto_where.detach().cpu().numpy()

# %% [markdown]
# ### Defining a Training Function

# %% [markdown]
# First, we define a helper function to update the training progress bar with key metrics:
#
# Displayed Metrics:
#
# - Train and Test Loss: The loss values during training and testing
# - Train and Test Step Acc: The average accuracy of each action
# - Train and Test Maze Acc: The average accuracy of the full trajectory predicted, measuring how many trajectories the CTM predicts perfectly
# - Statistics on the internal ticks:
#     - Average internal tick where the model has highest certainty
#     - Standard deviation of these certainty peaks
#     - Range (min ↔ max) of internal ticks where peak certainty occurs
#     - The position upto which the loss is taken, on average

# %%
def make_pbar_desc(train_loss, train_accuracy_step, train_accuracy_maze, test_loss, test_accuracy_step, test_accuracy_maze, lr, where_most_certain, upto_where):
    """A helper function to create a description for the tqdm progress bar"""
    pbar_desc = (
        f"Train Loss={train_loss:0.3f}. "
        f"Train Step Acc={train_accuracy_step:0.3f}. "
        f"Train Maze Acc={train_accuracy_maze:0.3f}. "
        f"Test Loss={test_loss:0.3f}. "
        f"Test Step Acc={test_accuracy_step:0.3f}. "
        f"Test Maze Acc={test_accuracy_maze:0.3f}. "
        f"LR={lr:0.6f}. "
    )
    pbar_desc += (
        f"Where_certain={where_most_certain.float().mean().item():0.2f}"
        f"+-{where_most_certain.float().std().item():0.2f} "
        f"({where_most_certain.min().item():d}<->{where_most_certain.max().item():d}). "
        f"Upto={sum(upto_where) / len(upto_where):0.2f}."
    )
    return pbar_desc

# %%
def update_training_curve_plot(fig, ax1, ax2, train_losses, test_losses, train_accuracies_step, train_accuracies_maze, test_accuracies_step, test_accuracies_maze, steps):
    clear_output(wait=True)
    
    # Plot loss
    ax1.clear()
    ax1.plot(range(len(train_losses)), train_losses, 'b-', alpha=0.7, label=f'Train Loss: {train_losses[-1]:.3f}')
    ax1.plot(steps, test_losses, 'r-', marker='o', label=f'Test Loss: {test_losses[-1]:.3f}')
    ax1.set_title('Loss')
    ax1.set_xlabel('Step')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Plot accuracy (step and maze)
    ax2.clear()
    ax2.plot(range(len(train_accuracies_step)), train_accuracies_step, 'b-', alpha=0.7, label=f'Train Step Acc: {train_accuracies_step[-1]:.3f}')
    ax2.plot(range(len(train_accuracies_maze)), train_accuracies_maze, 'g--', alpha=0.7, label=f'Train Maze Acc: {train_accuracies_maze[-1]:.3f}')
    ax2.plot(steps, test_accuracies_step, 'r-', marker='o', label=f'Test Step Acc: {test_accuracies_step[-1]:.3f}')
    ax2.plot(steps, test_accuracies_maze, color='orange', linestyle='--', marker='o', label=f'Test Maze Acc: {test_accuracies_maze[-1]:.3f}')
    ax2.set_title('Accuracy')
    ax2.set_xlabel('Step')
    ax2.set_ylabel('Accuracy')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    display(fig)

# %%
def train(model, trainloader, testloader, device='cpu', training_iterations=10000, test_every=1000, checkpoint_every=10000, lr=1e-4, log_dir='./logs'):

    def get_latest_checkpoint(log_dir):
        files = [f for f in os.listdir(log_dir) if re.match(r'checkpoint_\d+\.pt', f)]
        return os.path.join(log_dir, max(files, key=lambda f: int(re.search(r'\d+', f).group()))) if files else None

    os.makedirs(log_dir, exist_ok=True)

    model.train()
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr)

    if latest_checkpoint_path := get_latest_checkpoint(log_dir):
        checkpoint = torch.load(f'{latest_checkpoint_path}', weights_only=False)
        model.load_state_dict(checkpoint['model_state_dict'], strict=True)
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        train_losses = checkpoint['train_losses']
        test_losses = checkpoint['test_losses']
        train_accuracies_step = checkpoint['train_accuracies_step']
        train_accuracies_maze = checkpoint['train_accuracies_maze']
        test_accuracies_step = checkpoint['test_accuracies_step']
        test_accuracies_maze = checkpoint['test_accuracies_maze']
        steps = checkpoint['steps']
        start_iter = checkpoint['step']
    else:
        train_losses = []
        test_losses = []
        train_accuracies_step = []
        train_accuracies_maze = []
        test_accuracies_step = []
        test_accuracies_maze = []
        steps = []
        start_iter = 0
    
    iterator = iter(trainloader)


    plt.ion()
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    with tqdm(total=training_iterations, initial=start_iter) as pbar:
        for stepi in range(start_iter, training_iterations):
            try:
                inputs, targets = next(iterator)
            except StopIteration:
                iterator = iter(trainloader)
                inputs, targets = next(iterator)
    
            inputs, targets = inputs.to(device), targets.to(device)
            
            optimizer.zero_grad()
            
            predictions_raw, certainties, _ = model(inputs)

            # Reshape predictions to (B, S*5, T) where S is the route length and 5 is the number of actions (Up, Down, Left, Right, Wait)
            predictions = predictions_raw.reshape(predictions_raw.size(0), -1, 5, predictions_raw.size(-1)) # (B, S*5, T) -> (B, S, 5, T)
            
            # Compute loss
            train_loss, where_most_certain, upto_where = maze_loss(predictions, certainties, targets, use_most_certain=True)

            train_loss.backward()
            optimizer.step()

            train_losses.append(train_loss.item())

            train_predictions_most_certain = predictions.argmax(2)[torch.arange(predictions.size(0), device=predictions.device), :, where_most_certain] # (B, S, T) -> (B, S)

            # Calculate the accuracy of each step
            train_accuracy_step = (train_predictions_most_certain == targets).float().mean().item() # Scalar
            # Calculate the accuracy of the entire maze
            train_accuracy_maze = (train_predictions_most_certain == targets).all(-1).float().mean().item() # Scalar
            train_accuracies_step.append(train_accuracy_step)
            train_accuracies_maze.append(train_accuracy_maze)

            if stepi % test_every == 0 or stepi == 0:
                model.eval()
                with torch.no_grad():
                    all_test_predictions = []
                    all_test_targets = []
                    all_test_where_most_certain = []
                    all_test_losses = []
                    for inputs, targets in testloader:
                        inputs = inputs.to(device)
                        targets = targets.to(device)
                        
                        predictions_raw, certainties, _ = model(inputs)
                        predictions = predictions_raw.reshape(predictions_raw.size(0), -1, 5, predictions_raw.size(-1))
                        
                        test_loss, where_most_certain_test, _ = maze_loss(predictions, certainties, targets, use_most_certain=True)
                        all_test_losses.append(test_loss.item())
                        all_test_predictions.append(predictions)
                        all_test_targets.append(targets)
                        all_test_where_most_certain.append(where_most_certain_test)
                    
                    all_test_predictions = torch.cat(all_test_predictions, dim=0)
                    all_test_targets = torch.cat(all_test_targets, dim=0)
                    all_test_where_most_certain = torch.cat(all_test_where_most_certain, dim=0)
                    
                    test_loss = sum(all_test_losses) / len(all_test_losses)
                    test_losses.append(test_loss)

                    # Calculate the prediction at the most certain internal tick
                    all_test_predictions_most_certain = all_test_predictions.argmax(2)[torch.arange(all_test_predictions.size(0), device=predictions.device), :, all_test_where_most_certain] # (B, S, T) -> (B, S)
                    # Calculate the accuracy of each step
                    test_accuracy_step = (all_test_predictions_most_certain == all_test_targets).float().mean().item() # Scalar
                    # Calculate the accuracy of the entire maze
                    test_accuracy_maze = (all_test_targets == all_test_predictions_most_certain).all(-1).float().mean().item() # Scalar
                    test_accuracies_step.append(test_accuracy_step)
                    test_accuracies_maze.append(test_accuracy_maze)

                    steps.append(stepi)

                    create_maze_gif_visualization(model, testloader, device, log_dir)
                model.train()

                update_training_curve_plot(fig, ax1, ax2, train_losses, test_losses, train_accuracies_step, train_accuracies_maze, test_accuracies_step, test_accuracies_maze, steps)
            
            if stepi % checkpoint_every == 0 or stepi == training_iterations - 1:
                # Save the model checkpoint
                checkpoint_path = os.path.join(log_dir, f'checkpoint_{stepi}.pt')
                torch.save({
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'step': stepi,
                    'steps': steps,
                    'train_losses': train_losses,
                    'test_losses': test_losses,
                    'train_accuracies_step': train_accuracies_step,
                    'train_accuracies_maze': train_accuracies_maze,
                    'test_accuracies_step': test_accuracies_step,
                    'test_accuracies_maze': test_accuracies_maze,
                }, checkpoint_path)
                
            # Update the progress bar description
            pbar_desc = make_pbar_desc(train_loss=train_losses[-1], train_accuracy_step=train_accuracies_step[-1], train_accuracy_maze=train_accuracies_maze[-1], test_loss=test_losses[-1], test_accuracy_step=test_accuracies_step[-1], test_accuracy_maze=test_accuracies_maze[-1], lr=optimizer.param_groups[-1]["lr"], where_most_certain=where_most_certain, upto_where=upto_where)
            pbar.set_description(pbar_desc)
            pbar.update(1)
                    

    plt.ioff()
    plt.close(fig)
    return model

def create_maze_gif_visualization(model, testloader, device, log_dir):
    model.eval()
    with torch.no_grad():
        inputs_viz, targets_viz = next(iter(testloader))
        inputs_viz = inputs_viz.to(device)
        targets_viz = targets_viz.to(device)
        
        batch_index_to_viz = 0
        
        predictions_raw, certainties, _, pre_activations, post_activations, attention_tracking = model(inputs_viz, track=True)
        
        # Reshape predictions
        predictions = predictions_raw.reshape(predictions_raw.size(0), -1, 5, predictions_raw.size(-1))
        
        # Reshape attention tracking for visualization
        att_shape = (model.kv_features.shape[2], model.kv_features.shape[3])
        attention_tracking = attention_tracking.reshape(attention_tracking.shape[0], attention_tracking.shape[1], -1, att_shape[0], att_shape[1])

        plot_neural_dynamics(post_activations, 100, log_dir, axis_snap=True)
        
        # Create maze GIF with attention visualization
        maze_input = (inputs_viz[batch_index_to_viz].detach().cpu().numpy() + 1) / 2
        maze_predictions = predictions[batch_index_to_viz].detach().cpu().numpy()
        maze_targets = targets_viz[batch_index_to_viz].detach().cpu().numpy()
        maze_attention = attention_tracking[:, batch_index_to_viz] if attention_tracking.ndim > 2 else attention_tracking

        # Generate the maze GIF
        make_maze_gif(
            maze_input,
            maze_predictions,
            maze_targets,
            maze_attention,
            log_dir
        )
        
        predictions_raw, certainties, _ = model(inputs_viz)
        predictions = predictions_raw.reshape(predictions_raw.size(0), -1, 5, predictions_raw.size(-1))

# %% [markdown]
# ### Initializing the CTM
# Finally, we initialize the CTM. The model we define below is significantly larger than that used in the MNIST tutorial. Here we use `d_model=1024`, corresponding to the size of the activated state, and therefore the number of Neuron Level Models. Try adjusting this and other hyperparameters to see how it affects the total number of parameters.
#
# Other hyperparameters that are of note and differ from the MNIST tutorial are:
# 1) `prediction_reshaper=[50, 5]`: used for reshaping the predictions during the certainty calculate in the CTMs forward pass. `50` and `5` correspond to the sequence length and number of possible actions respectively
# 2) `positional_embedding_type='none'`: no positional embeddings are used, encouraging the CTM to form a world model. See section 4.4 of the technical report for a discussion on this.
# 3) `neuron_select_type='random-pairing'`: this hyperparameter determines how neurons will be selected for synchronization. While in the MNIST tutorial we used the first and last neurons, here we select `n_synch_out=256` and `n_synch_action=256` random **pairs** of neurons for predictions and attention queries respectively.

# %%
# Set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Define the model
model = CTM(
    iterations=50,
    d_model=1024,
    d_input=256,
    heads=8,
    n_synch_out=256,
    n_synch_action=256,
    synapse_depth=8,
    memory_length=15,
    deep_nlms=True,
    memory_hidden_dims=16,
    backbone_type='resnet34-2',
    out_dims=50 * 5,
    prediction_reshaper=[50, 5],
    dropout=0.1,
    do_layernorm_nlm=False,
    positional_embedding_type='none',
    neuron_select_type='random-pairing',  
).to(device)

# Initialize model parameters with dummy forward pass
sample_batch = next(iter(trainloader))
dummy_input = sample_batch[0][:1].to(device)
with torch.no_grad():
    _ = model(dummy_input)

print(f'Model parameters: {sum(p.numel() for p in model.parameters()):,}')
# Out:
# Using neuron select type: random-pairing
# Synch representation size action: 256
# Synch representation size out: 256
# Model parameters: 8,561,144

# %%
model = train(model=model, trainloader=trainloader, testloader=testloader, device=device, training_iterations=100001, test_every=1000, checkpoint_every=10000, lr=1e-4, log_dir='./maze_logs')

# %% [markdown]
# Visualise a gif of a solution

# %%
reader = imageio.get_reader("maze_logs/prediction.gif")
frames = [reader.get_data(i) for i in range(min(len(reader), 100))]
mediapy.show_video(frames, width=400, codec="gif")
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="400" height="250" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>
